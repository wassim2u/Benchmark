# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset
import seaborn as sns


from IPython.display import display
pd.set_option('display.max_columns', None)

# %%
CSV_metrics_folder = "metric_logs/"
FIG_FOLDER = "./analysis/"

# %%
def preprocess_text_wmt14(examples):
    inputs = [ex["en"] for ex in examples["translation"]]
    targets = [ex["fr"] for ex in examples["translation"]]
    text_df = pd.DataFrame({'en':inputs, 'fr':targets})
    return text_df

def preprocess_text_flores200(dataset_src, dataset_tgt):    
    inputs = dataset_flores200_eng['sentence']
    targets = dataset_flores200_fra['sentence']
    text_df = pd.DataFrame({'en':inputs, 'fr':targets})
    return text_df


def num_of_words_in_lang_dataset(df, lang_code):
    df['word_count' + "_" + lang_code] = df[lang_code].apply(lambda x : len(str(x).split(" ")))
    return df


def describe_dataset_df(text_df, dataset_name, save_filename, x_axis="Sequence Length", cumulative=False, save=False):
    text_df = num_of_words_in_lang_dataset(text_df, 'en')
    text_df = num_of_words_in_lang_dataset(text_df, 'fr')
    plt.figure(figsize=(10, 6)) 

    plt.subplot(1, 2, 1)

    display(text_df.head(10))
    display(text_df.describe())

    plt.hist(text_df["word_count_en"], bins=100, cumulative = cumulative,label = 'en')

    
    plt.axvline(x=15, color="red")
    plt.axvline(x=30, color="red")
    plt.axvline(x=82, color="red")
    plt.title(dataset_name + " Text Length Distribution")
    plt.xlabel(x_axis)
    plt.ylabel("Frequency")
    plt.legend(loc="upper right")
    # plt.show()

    plt.subplot(1, 2, 2)

    plt.hist(text_df["word_count_fr"], bins=100, color="orange", cumulative = cumulative ,label = 'fr')
    plt.title(dataset_name)

    plt.axvline(x=15, color="red")
    plt.axvline(x=30, color="red")
    plt.axvline(x=82, color="red")
    plt.title(dataset_name + " Text Length Distribution")
    plt.legend(loc="upper right")
    plt.xlabel(x_axis)
    plt.ylabel("Frequency")
    plt.tight_layout()

    if save:
        plt.savefig(save_filename,
        dpi=300,
        bbox_inches="tight")

    plt.show()

    return text_df

# %%
# Analyse WMT14  dataset
all_dataset_wmt14 = load_dataset("wmt14", "fr-en", split="validation")
all_dataset_wmt14

filtered_dataset= all_dataset_wmt14.filter(lambda example: print(len((example["translation"]["en"]).split(" "))))
filtered_dataset
# Out:
# Found cached dataset wmt14 (/home/wassim/.cache/huggingface/datasets/wmt14/fr-en/1.0.0/2de185b074515e97618524d69f5e27ee7545dcbed4aa9bc1a4235710ffca33f4)
# Loading cached processed dataset at /home/wassim/.cache/huggingface/datasets/wmt14/fr-en/1.0.0/2de185b074515e97618524d69f5e27ee7545dcbed4aa9bc1a4235710ffca33f4/cache-ffa021a3c9d40584.arrow
# Dataset({
#     features: ['translation'],
#     num_rows: 0
# })

# %%
wmt14_df = preprocess_text_wmt14(all_dataset_wmt14)
describe_dataset_df(wmt14_df, dataset_name="WMT14", save_filename="./wmt14_dataset_word_count.png", cumulative=False, save=True)
# describe_dataset_df(wmt14_df, dataset_name="WMT14", cumulative=True)


print(all_dataset_wmt14[0]["translation"]["en"])
# Out:
#                                                   en  \
# 0  A Republican strategy to counter the re-electi...
# 1  Republican leaders justified their policy by t...
# 2  However, the Brennan Centre considers this a m...
# 3  Indeed, Republican lawyers identified only 300...
# 4  One thing is certain: these new provisions wil...
# 5  In this sense, the measures will partially und...
# 6  Unlike in Canada, the American States are resp...
# 7  It is in this spirit that a majority of Americ...
# 8  This phenomenon gained momentum following the ...
# 9  As a result, 180 bills restricting the exercis...
#
#                                                   fr  word_count_en  \
# 0  Une stratégie républicaine pour contrer la réé...              9
# 1  Les dirigeants républicains justifièrent leur ...             12
# 2  Or, le Centre Brennan considère cette dernière...             26
# 3  D'ailleurs, les avocats républicains n'ont rec...             17
# 4  Une chose est certaine: ces nouvelles disposit...             15
# 5  En ce sens, ces mesures mineront en partie le ...             12
# 6  Contrairement au Canada, les États américains ...             18
# 7  C'est dans cet esprit qu'une majorité de gouve...             25
# 8  Ce phénomène a pris de l'ampleur après les éle...             19
# 9  En conséquence, 180 projets de lois restreigna...             21
#
#    word_count_fr
# 0              8
# 1             15
# 2             29
# 3             17
# 4             13
# 5             12
# 6             15
# 7             26
# 8             22
# 9             23
#        word_count_en  word_count_fr
# count    3000.000000    3000.000000
# mean       18.696000      20.517000
# std        10.998268      12.309842
# min         1.000000       1.000000
# 25%        11.000000      12.000000
# 50%        17.000000      18.000000
# 75%        24.000000      27.000000
# max        82.000000     100.000000
# A Republican strategy to counter the re-election of Obama

# %% [markdown]
# 1. *** Talk about the best-performing configuration.
#     1.1. Use the best-performing configuration on the Dense models for MoE model that you ran.
# 2.  Extra time: Show latency and throughput of largest sentence vs Latency and throughput of smallest sentence for each model and dataset (Need to run the experiments, but shouldn't take much time to setup.)
# 3. *** Talk about the beam size.
# 4. *** Describe how when you first ran the experiments, you got better results with lower max generation. then, since you were curious as to why that is, you researched to see  if padding makes any difference. That is why we chose to run experiments with padding and no padding
#     5. What we found out is there is no difference in the scores between padding and no padding.
# 6. Talk about latency and throughput. Investigate how they change with batch size, beam size, how they change with different models. See which one is the most efficient. Explain why they are efficient.
# 7. Some additional analysis: Explain how rerunning ... (?)
# 8.
# 9. Spend time generating nice figures
# 10. Show latency and throughout with and without using archer. Show memory utilisation with and without using archer.
# 11. **** Show latency of MoE vs without MoE, comparing parameter size.
# 12. Run beam size of 1,2,4,8 for three experiments.
# 13. **** Run NLLB-MoE for 1 infernence.
# 14. **** Report different settings of device_memory_ratio of the switch transformer trained.
# 15. Analyse the quality metrics that you see

# %% [markdown]
# ##

# %%
dataset_flores200_fra = load_dataset("facebook/flores", "fra_Latn", split="dev")
dataset_flores200_eng = load_dataset("facebook/flores", "eng_Latn", split="dev")

flores200_df = preprocess_text_flores200(dataset_flores200_eng, dataset_flores200_fra)
describe_dataset_df(flores200_df, dataset_name="FLORES-200", save_filename="flores_dataset_word_count.png" , cumulative=False, save=True)
# describe_dataset_df(flores200_df, dataset_name="FLORES-200", cumulative=True)


# plt.savefig(save_filename,
#     dpi=300,
#     bbox_inches="tight")
# Out:
# Found cached dataset flores (/home/wassim/.cache/huggingface/datasets/facebook___flores/fra_Latn/1.0.0/2a1174c8c4991ca09a9cb5b9a367cb2e049b073852cb4097456164d4612391ef)
# Found cached dataset flores (/home/wassim/.cache/huggingface/datasets/facebook___flores/eng_Latn/1.0.0/2a1174c8c4991ca09a9cb5b9a367cb2e049b073852cb4097456164d4612391ef)
#                                                   en  \
# 0  On Monday, scientists from the Stanford Univer...
# 1  Lead researchers say this may bring early dete...
# 2  The JAS 39C Gripen crashed onto a runway at ar...
# 3  The pilot was identified as Squadron Leader Di...
# 4  Local media reports an airport fire vehicle ro...
# 5  28-year-old Vidal had joined Barça three seaso...
# 6  Since moving to the Catalan-capital, Vidal had...
# 7  The protest started around 11:00 local time (U...
# 8  Just after 11:00, protesters blocked traffic o...
# 9  At 11:20, the police asked the protesters to m...
#
#                                                   fr  word_count_en  \
# 0  Des scientifiques de l’école de médecine de l’...             43
# 1  Selon les chercheurs principaux, cela pourrait...             36
# 2  Le JAS 39C Gripen s’est écrasé sur une piste a...             24
# 3  Le pilote a été identifié comme étant le chef ...              9
# 4  La presse locale a rapporté qu'un véhicule de ...             11
# 5  Vidal, 28 ans, avait rejoint le Barça il y a t...             10
# 6  Depuis son arrivée dans la capitale catalane, ...             13
# 7  La manifestation a commencé vers 11 h heure lo...             22
# 8  À Whitehall, peu après 11 h 00, des manifestan...             12
# 9  À 11 h 20, la police a demandé aux manifestant...             29
#
#    word_count_fr
# 0             59
# 1             53
# 2             26
# 3             12
# 4             20
# 5             16
# 6             15
# 7             29
# 8             19
# 9             29
#        word_count_en  word_count_fr
# count     997.000000     997.000000
# mean       21.018054      23.960883
# std         6.844051       8.086845
# min         6.000000       5.000000
# 25%        16.000000      18.000000
# 50%        20.000000      23.000000
# 75%        25.000000      29.000000
# max        48.000000      59.000000
#                                                     en  \
# 0    On Monday, scientists from the Stanford Univer...
# 1    Lead researchers say this may bring early dete...
# 2    The JAS 39C Gripen crashed onto a runway at ar...
# 3    The pilot was identified as Squadron Leader Di...
# 4    Local media reports an airport fire vehicle ro...
# ..                                                 ...
# 992  The tourist season for the hill stations gener...
# 993  However, they have a different kind of beauty ...
# 994  Only a few airlines still offer bereavement fa...
# 995  Airlines that offer these include Air Canada, ...
# 996  In all cases, you must book by phone directly ...
#
#                                                     fr  word_count_en  \
# 0    Des scientifiques de l’école de médecine de l’...             43
# 1    Selon les chercheurs principaux, cela pourrait...             36
# 2    Le JAS 39C Gripen s’est écrasé sur une piste a...             24
# 3    Le pilote a été identifié comme étant le chef ...              9
# 4    La presse locale a rapporté qu'un véhicule de ...             11
# ..                                                 ...            ...
# 992  La saison touristique des stations de montagne...             13
# 993  Cependant, leur beauté et leur charme évoluent...             29
# 994  Seules quelques compagnies aériennes proposent...             17
# 995  Les compagnies aériennes qui les proposent son...             21
# 996  Dans tous les cas, vous devez réserver par tél...             12
#
#      word_count_fr
# 0               59
# 1               53
# 2               26
# 3               12
# 4               20
# ..             ...
# 992             12
# 993             32
# 994             21
# 995             26
# 996             15
#
# [997 rows x 4 columns]

# %%
from transformers import AutoTokenizer

def ecdf_plot_two_datasets(dataset_df1, dataset_df2, label_1, label_2, x_axis, title, max_length=256, trunctuation=True, to_pad="do_not_pad", scale=None, save=False, save_filename=None):
    tokenizer = AutoTokenizer.from_pretrained("google/switch-base-128")
    def tokenize(dataset_df):
        
        all_inputs = (list(dataset_df["en"].values))
        all_inputs = [
            tokenizer(input, truncation=trunctuation, padding=to_pad,
                      max_length=max_length).input_ids for input in all_inputs
        ]
        lengths = [len(input) for input in all_inputs]

        return lengths

    lengths_1 = tokenize(dataset_df1)
    lengths_2 = tokenize(dataset_df2)
    plt.figure()
    sns.ecdfplot(lengths_1, label=label_1)
    sns.ecdfplot(lengths_2, label= label_2)

    plt.xlabel(x_axis)
    plt.title(title)
    plt.legend()
    if scale == "log":
        plt.xscale("log")
    if save:
        plt.savefig(save_filename,
            dpi=300,
            bbox_inches="tight")

# %% [markdown]
# ECDF Plot of all inputs, french and english. Exploring differences in the length of news text between true & fake news
#
# The ecdf Plot has the same trend for word count of french only, and english only.

# %%
ecdf_plot_two_datasets(wmt14_df, flores200_df, save=True, save_filename=FIG_FOLDER + "ecdf_word_count_wmt14_flores.png", label_1="WMT14", label_2="FLORES-200" , x_axis= "Word Count", title="ECDF of Word Count in WMT14 and FLORES-200")


# print(type(all_inputs[0]))

# # get token ids from all_inputs type tokenizers.Encoding
# all_inputs = all_inputs[-1].ids

# %%
# !ls ~/Benchmark/metric_logs
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# nllb-200-distilled-600M_flores200_metrics.csv
# nllb-200-distilled-600M_wmt14_metrics.csv
# nllb-moe-54b_flores200_metrics.csv
# nllb-moe-54b_wmt14_archer_0.6_metrics.csv
# nllb-moe-54b_wmt14_metrics.csv
# nllb-moe-54b_wmt14_metrics.csv_archer_0.6.csv
# nllb-moe_latencies.csv
# opus_switch_model_16
# switch_16_finetuned_flores200_metrics.csv
# switch_16_finetuned_flores200_metrics.csv_archer_0.1.csv
# switch_16_finetuned_wmt14_archer_0.3_metrics.csv
# switch_16_finetuned_wmt14_archer_0.9_metrics.csv
# switch_16_finetuned_wmt14_metrics.csv
# switch_16_finetuned_wmt14_metrics.csv_archer_0.1.csv
# switch_16_finetuned_wmt14_metrics.csv_archer_0.3.csv
# switch_16_finetuned_wmt14_metrics.csv_archer_0.6.csv
# switch-base-128_flores200_metrics.csv
# switch-base-128_wmt14_metrics.csv
# switch_latencies.csv
# t5-base_flores200_metrics.csv
# t5-base_wmt14_metrics.csv
# t5-large_flores200_metrics.csv
# t5-large_wmt14_metrics.csv
# t5_latencies.csv

# %%
def ecdf_plot_metric(metric_df, metric_name, title, scale=None, save=False, save_filename=None):
    
    plt.figure()
    sns.ecdfplot(dataset_df[metric_name], label=metric_name)
    

    plt.xlabel(metric_name)
    plt.title(title)
    if scale == "log":
        plt.xscale("log")
    if save:
        plt.savefig(save_filename,
            dpi=300,
            bbox_inches="tight")

# %%
# Analyse the experiments!
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(CSV_metrics_folder + "nllb-200-distilled-600M_wmt14_metrics.csv")
data = data.sort_values(by=['sacrebleu'], ascending=False)
data
# Out:
#                            model_name  total_params  use_archer  \
# 76   facebook/nllb-200-distilled-600M     615073792       False
# 72   facebook/nllb-200-distilled-600M     615073792       False
# 93   facebook/nllb-200-distilled-600M     615073792       False
# 94   facebook/nllb-200-distilled-600M     615073792       False
# 95   facebook/nllb-200-distilled-600M     615073792       False
# ..                                ...           ...         ...
# 21   facebook/nllb-200-distilled-600M     615073792       False
# 12   facebook/nllb-200-distilled-600M     615073792       False
# 147  facebook/nllb-200-distilled-600M     615073792       False
# 148  facebook/nllb-200-distilled-600M     615073792       False
# 0    facebook/nllb-200-distilled-600M     615073792       False
#
#      device_memory_ratio dataset_name  dataset_size  \
# 76                   NaN        wmt14             1
# 72                   NaN        wmt14             1
# 93                   NaN        wmt14             1
# 94                   NaN        wmt14             1
# 95                   NaN        wmt14             1
# ..                   ...          ...           ...
# 21                   NaN        wmt14          3000
# 12                   NaN        wmt14          3000
# 147                  NaN        wmt14          3000
# 148                  NaN        wmt14          3000
# 0                    NaN        wmt14          3000
#
#      dataset_size_after_filter_wrt_input_len src_lang tgt_lang  batch_size  \
# 76                                         1       en       fr          32
# 72                                         1       en       fr          32
# 93                                         1       en       fr          32
# 94                                         1       en       fr          32
# 95                                         1       en       fr          32
# ..                                       ...      ...      ...         ...
# 21                                       710       en       fr          32
# 12                                       710       en       fr          32
# 147                                      710       en       fr          32
# 148                                      710       en       fr          32
# 0                                        710       en       fr          32
#
#      beam_size  max_gen_length  max_input_seq_length  \
# 76           2             128                    10
# 72           1              64                    10
# 93           1             512                    10
# 94           2             512                    10
# 95           4             512                    10
# ..         ...             ...                   ...
# 21           1             512                    10
# 12           1              64                    10
# 147          1             128                    10
# 148          1             128                    10
# 0            1              64                    10
#
#     tokenizer_padding_setting   sacrebleu      spBleu        chrf      chrfpp  \
# 76          pad_to_max_length  100.000000  100.000000  100.000000  100.000000
# 72          pad_to_max_length  100.000000  100.000000  100.000000  100.000000
# 93                 do_not_pad  100.000000  100.000000  100.000000  100.000000
# 94                 do_not_pad  100.000000  100.000000  100.000000  100.000000
# 95                 do_not_pad  100.000000  100.000000  100.000000  100.000000
# ..                        ...         ...         ...         ...         ...
# 21                 do_not_pad   31.508888   35.955283   55.634936   53.471797
# 12                 do_not_pad   31.508888   35.955283   55.634936   53.471797
# 147                do_not_pad   31.508888   35.955283   55.634936   53.471797
# 148         pad_to_max_length   31.508888   35.955283   55.634936   53.471797
# 0           pad_to_max_length   31.508888   35.955283   55.634936   53.471797
#
#        meteor   gen_len  encoder_latency_s  decoder_latency_s  \
# 76   0.999023  20.00000           0.008513           0.006018
# 72   0.999023  20.00000           0.008186           0.006386
# 93   0.999023  20.00000           0.008526           0.005862
# 94   0.999023  20.00000           0.009160           0.005976
# 95   0.999023  20.00000           0.007930           0.006012
# ..        ...       ...                ...                ...
# 21   0.561438  15.86338           0.005074           0.005846
# 12   0.561438  15.86338           0.005123           0.006068
# 147  0.561438  15.86338           0.004888           0.005865
# 148  0.561438  15.86338           0.005828           0.005689
# 0    0.561438  15.86338           0.005887           0.005861
#
#      encoder_throughput  decoder_throughput
# 76         1.762042e+03        3.323215e+03
# 72         1.832355e+03        3.131951e+03
# 93         1.759380e+03        3.411947e+03
# 94         1.637562e+03        3.346714e+03
# 95         1.891546e+03        3.326832e+03
# ..                  ...                 ...
# 21         1.714289e+06        1.926499e+06
# 12         1.698039e+06        1.856049e+06
# 147        1.779567e+06        1.920369e+06
# 148        1.492729e+06        1.979801e+06
# 0          1.477760e+06        1.921840e+06
#
# [152 rows x 24 columns]

# %%
import os
# Merge all metrics to one table
csv_files = os.listdir( CSV_metrics_folder )

files_df_dict = {}
# This would print all the files and directories
for file in csv_files:
    if "metric" in file: 
        data= pd.read_csv(CSV_metrics_folder + file)
        files_df_dict[file] = data

df_merge_all = pd.concat(files_df_dict.values(), ignore_index=True)
df_merge_all = df_merge_all.fillna(False)
df_merge_all = df_merge_all[df_merge_all["beam_size"] <=32]
df_merge_all = df_merge_all[df_merge_all["max_gen_length"] <=128]
df_merge_all = df_merge_all.drop_duplicates()

df_merge_all
# Out:
#                            model_name  total_params  use_archer dataset_name  \
# 0          google/switch_16_finetuned           630        True    flores200
# 1          google/switch_16_finetuned           630        True    flores200
# 2          google/switch_16_finetuned           630        True    flores200
# 3          google/switch_16_finetuned           630        True    flores200
# 4          google/switch_16_finetuned           630        True    flores200
# ..                                ...           ...         ...          ...
# 401  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 402  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 403  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 404        google/switch_16_finetuned           630        True        wmt14
# 405        google/switch_16_finetuned           630        True        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 0               1                                        1       en       fr
# 1               1                                        1       en       fr
# 2               1                                        1       en       fr
# 3               1                                        1       en       fr
# 4               1                                        1       en       fr
# ..            ...                                      ...      ...      ...
# 401           997                                      997       en       fr
# 402           997                                      997       en       fr
# 403           997                                      199       en       fr
# 404             1                                        1       en       fr
# 405          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 0            32          1              20                    -1
# 1            32          2              20                    -1
# 2            32          4              20                    -1
# 3            32          8              20                    -1
# 4            32          1              32                    -1
# ..          ...        ...             ...                   ...
# 401          32          2             128                    -1
# 402          32          4             128                    -1
# 403          32          1             128                    15
# 404          32          1              32                    -1
# 405          32          1              32                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 0                 no_pad_fill   0.153957   0.057383  13.904675  13.002759
# 1                 no_pad_fill   0.116982   0.078797  15.141226  12.993410
# 2                 no_pad_fill   0.144581   0.089809  18.472260  15.964222
# 3                 no_pad_fill   0.144581   0.089809  18.472260  15.964222
# 4                 no_pad_fill   0.705569   0.415819  20.831155  18.814175
# ..                        ...        ...        ...        ...        ...
# 401         pad_to_max_length  46.588451  50.587039  68.895572  66.947755
# 402         pad_to_max_length  47.209741  51.276877  69.381455  67.416364
# 403         pad_to_max_length  46.658401  50.764583  69.026598  67.145934
# 404               no_pad_fill   9.980099  15.733206  66.321237  57.459280
# 405               no_pad_fill   6.121815   7.247041  27.393845  25.376740
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 0    0.072115  19.000000           4.617972           0.179913
# 1    0.048077  19.000000           0.076106           0.048656
# 2    0.064103  19.000000           0.068468           0.047508
# 3    0.064103  19.000000           0.072908           0.041661
# 4    0.103011  31.000000           0.074672           0.025436
# ..        ...        ...                ...                ...
# 401  0.696386  39.769308           0.005532           0.005898
# 402  0.700522  40.112337           0.009295           0.005962
# 403  0.699213  25.733668           0.005244           0.005761
# 404  0.384909  13.000000           3.449954           0.212142
# 405  0.261448  26.332000           0.101974           0.063782
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 0          1.299272e+01        1.056067e+02               False
# 1          7.883693e+02        3.904955e+02               False
# 2          8.763164e+02        3.999328e+02               False
# 3          8.229514e+02        4.560648e+02               False
# 4          8.035136e+02        1.218762e+03               False
# ..                  ...                 ...                 ...
# 401        5.585562e+06        6.722573e+06               False
# 402        3.324243e+06        6.707889e+06               False
# 403        7.495831e+05        8.888984e+05               False
# 404        5.507320e+00        6.127983e+01                 0.3
# 405        9.326726e+05        1.238524e+06                 0.3
#
# [305 rows x 24 columns]

# %%
df_merge_wmt14 = df_merge_all[df_merge_all["dataset_name"] == "wmt14"]
df_merge_flores200 = df_merge_all[df_merge_all["dataset_name"] == "flores200"]

df_merge_wmt14 = df_merge_wmt14.sort_values(by=['sacrebleu'], ascending=False)
df_merge_flores200 = df_merge_flores200.sort_values(by=['sacrebleu'], ascending=False)

# %%
display(df_merge_wmt14)
df_merge_wmt14.describe()
# Out:
#                            model_name  total_params  use_archer dataset_name  \
# 268  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 122                           t5-base     222903552       False        wmt14
# 120                           t5-base     222903552       False        wmt14
# 119                           t5-base     222903552       False        wmt14
# 118                           t5-base     222903552       False        wmt14
# ..                                ...           ...         ...          ...
# 62              facebook/nllb-moe-54b     524717009       False        wmt14
# 63              facebook/nllb-moe-54b     524717009       False        wmt14
# 64              facebook/nllb-moe-54b     524717009       False        wmt14
# 65              facebook/nllb-moe-54b     524717009       False        wmt14
# 34             google/switch-base-128          3318       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 268             1                                        1       en       fr
# 122             1                                        1       en       fr
# 120             1                                        1       en       fr
# 119             1                                        1       en       fr
# 118             1                                        1       en       fr
# ..            ...                                      ...      ...      ...
# 62              1                                        1       en       fr
# 63              1                                        1       en       fr
# 64              1                                        1       en       fr
# 65              1                                        1       en       fr
# 34              1                                        1       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 268          32          4             128                    -1
# 122          32          2             128                    30
# 120          32          4             128                    30
# 119          32          2             128                    30
# 118          32          1             128                    30
# ..          ...        ...             ...                   ...
# 62            1          4              64                    -1
# 63            1          1             128                    -1
# 64            1          2             128                    -1
# 65            1          4             128                    -1
# 34           16          4             128                    -1
#
#     tokenizer_padding_setting  sacrebleu  spBleu        chrf      chrfpp  \
# 268         pad_to_max_length      100.0   100.0  100.000000  100.000000
# 122                do_not_pad      100.0   100.0  100.000000  100.000000
# 120         pad_to_max_length      100.0   100.0  100.000000  100.000000
# 119         pad_to_max_length      100.0   100.0  100.000000  100.000000
# 118         pad_to_max_length      100.0   100.0  100.000000  100.000000
# ..                        ...        ...     ...         ...         ...
# 62                no_pad_fill        0.0     0.0   11.262631    8.446974
# 63                no_pad_fill        0.0     0.0    7.124413    5.343310
# 64                no_pad_fill        0.0     0.0    8.011914    6.008936
# 65                no_pad_fill        0.0     0.0    7.739168    5.804376
# 34          pad_to_max_length        0.0     0.0   17.069391   12.802043
#
#        meteor  gen_len  encoder_latency_s  decoder_latency_s  \
# 268  0.999023     20.0           0.007933           0.006055
# 122  0.999023     19.0           0.008434           0.006907
# 120  0.999023     19.0           0.008553           0.007417
# 119  0.999023     19.0           0.008673           0.006889
# 118  0.999023     19.0           0.009676           0.006960
# ..        ...      ...                ...                ...
# 62   0.000000     64.0           1.231458           0.456350
# 63   0.000000    128.0           1.172449           0.114301
# 64   0.000000    128.0           1.234269           0.178055
# 65   0.000000    128.0           1.221783           0.343588
# 34   0.000000     20.0           5.396237           0.365660
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 268         1890.909000         3303.248277               False
# 122         2252.685800         2750.766326               False
# 120         2221.479500         2561.636341               False
# 119         2190.631000         2757.879805               False
# 118         1963.562000         2729.787343               False
# ..                  ...                 ...                 ...
# 62            17.052952          140.243105               False
# 63            17.911232         1119.852697               False
# 64            17.014116          718.878269               False
# 65            17.187994          372.539494               False
# 34             3.520972           54.695587               False
#
# [180 rows x 24 columns]
#        total_params  dataset_size  dataset_size_after_filter_wrt_input_len  \
# count  1.800000e+02    180.000000                               180.000000
# mean   5.062919e+08   1367.211111                               970.755556
# std    2.286520e+08   1497.730458                              1233.776849
# min    6.300000e+02      1.000000                                 1.000000
# 25%    2.229036e+08      1.000000                                 1.000000
# 50%    6.150738e+08      1.000000                                 1.000000
# 75%    6.150738e+08   3000.000000                              2627.000000
# max    7.376681e+08   3000.000000                              3000.000000
#
#        batch_size   beam_size  max_gen_length  max_input_seq_length  \
# count  180.000000  180.000000      180.000000            180.000000
# mean    28.961111    2.361111      105.400000             11.322222
# std      8.690433    1.670526       35.264935             12.690407
# min      1.000000    1.000000       20.000000             -1.000000
# 25%     32.000000    1.000000       64.000000             -1.000000
# 50%     32.000000    2.000000      128.000000             10.000000
# 75%     32.000000    4.000000      128.000000             30.000000
# max     32.000000   16.000000      128.000000             30.000000
#
#         sacrebleu      spBleu        chrf      chrfpp      meteor     gen_len  \
# count  180.000000  180.000000  180.000000  180.000000  180.000000  180.000000
# mean    55.274678   57.502576   69.487270   67.899995    0.673161   26.834056
# std     38.468160   37.072120   29.135536   30.230358    0.320558   17.810198
# min      0.000000    0.000000    1.534227    1.973425    0.000000    9.000000
# 25%     31.720647   36.278615   56.854466   54.708607    0.564121   19.000000
# 50%     33.465918   37.748448   58.600671   56.459357    0.583804   20.000000
# 75%    100.000000  100.000000  100.000000  100.000000    0.999023   32.000000
# max    100.000000  100.000000  100.000000  100.000000    0.999023  128.000000
#
#        encoder_latency_s  decoder_latency_s  encoder_throughput  \
# count         180.000000         180.000000        1.800000e+02
# mean            1.916718           0.100274        3.402756e+06
# std             9.481421           0.391049        4.970806e+06
# min             0.004888           0.005415        3.320994e-01
# 25%             0.006149           0.005950        1.615082e+03
# 50%             0.008648           0.006994        2.242311e+03
# 75%             0.012627           0.014885        6.403382e+06
# max            63.234093           3.492991        1.542428e+07
#
#        decoder_throughput
# count        1.800000e+02
# mean         3.893488e+06
# std          5.957500e+06
# min          8.043121e+00
# 25%          2.557993e+03
# 50%          3.488214e+03
# 75%          5.307985e+06
# max          1.857388e+07

# %%
df_merge_flores200
# Out:
#                            model_name  total_params  use_archer dataset_name  \
# 339                           t5-base     222903552       False    flores200
# 336                           t5-base     222903552       False    flores200
# 402  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 390  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 378  facebook/nllb-200-distilled-600M     615073792       False    flores200
# ..                                ...           ...         ...          ...
# 43              facebook/nllb-moe-54b     524717009       False    flores200
# 44              facebook/nllb-moe-54b     524717009       False    flores200
# 50              facebook/nllb-moe-54b     524717009       False    flores200
# 45              facebook/nllb-moe-54b     524717009       False    flores200
# 47              facebook/nllb-moe-54b     524717009       False    flores200
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 339           997                                      199       en       fr
# 336           997                                      199       en       fr
# 402           997                                      997       en       fr
# 390           997                                      898       en       fr
# 378           997                                      898       en       fr
# ..            ...                                      ...      ...      ...
# 43              1                                        1       en       fr
# 44              1                                        1       en       fr
# 50              1                                        1       en       fr
# 45              1                                        1       en       fr
# 47              1                                        1       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 339          32          4             128                    15
# 336          32          4             128                    15
# 402          32          4             128                    -1
# 390          32          4             128                    30
# 378          32          4             128                    30
# ..          ...        ...             ...                   ...
# 43            1          1              32                    -1
# 44            1          2              32                    -1
# 50            1          2             128                    -1
# 45            1          4              32                    -1
# 47            1          2              64                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 339                do_not_pad  47.277472  51.984123  68.478459  66.844419
# 336         pad_to_max_length  47.277472  51.984123  68.478459  66.844419
# 402         pad_to_max_length  47.209741  51.276877  69.381455  67.416364
# 390                do_not_pad  47.106364  51.248931  69.350990  67.380539
# 378         pad_to_max_length  47.106364  51.248931  69.350990  67.380539
# ..                        ...        ...        ...        ...        ...
# 43                no_pad_fill   0.000000   0.000000   8.191595   6.143696
# 44                no_pad_fill   0.000000   0.000000   5.232567   3.924425
# 50                no_pad_fill   0.000000   0.000000  12.570967   9.428225
# 45                no_pad_fill   0.000000   0.000000   5.932701   4.449526
# 47                no_pad_fill   0.000000   0.000000   8.038266   6.028699
#
#        meteor     gen_len  encoder_latency_s  decoder_latency_s  \
# 339  0.687672   28.793970           0.006009           0.007937
# 336  0.687672   28.793970           0.006225           0.007850
# 402  0.700522   40.112337           0.009295           0.005962
# 390  0.701068   37.630290           0.006420           0.005887
# 378  0.701068   37.630290           0.006289           0.005758
# ..        ...         ...                ...                ...
# 43   0.000000   32.000000           2.428121           0.375891
# 44   0.000000   32.000000           2.590492           0.506387
# 50   0.000000  128.000000           6.307121           0.638252
# 45   0.000000   32.000000           2.427577           1.587874
# 47   0.000000   64.000000           2.420364           0.742790
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 339        7.781424e+05        7.219797e+05               False
# 336        7.511659e+05        7.299693e+05               False
# 402        3.324243e+06        6.707889e+06               False
# 390        4.063707e+06        5.739691e+06               False
# 378        4.148722e+06        5.868786e+06               False
# ..                  ...                 ...                 ...
# 43         2.635783e+01        8.513108e+01               False
# 44         2.470573e+01        6.319283e+01               False
# 50         1.014726e+01        2.005478e+02               False
# 45         2.636373e+01        2.015273e+01               False
# 47         2.644230e+01        8.616159e+01               False
#
# [125 rows x 24 columns]

# %% [markdown]
# ## Size after filtering out by input sequence length

# %%
def dataset_size_after_filtering_sequence_length(df, seq_len_col="max_input_seq_length"):
    df_multiple_experiments = df[df["dataset_size"] != 1]
    dataset_size = 0
    dataset_size = df_multiple_experiments["dataset_size"].max()
    
    seq_lens = []
    dataset_sizes_after_filterss = []
    for seq_len in df_multiple_experiments[seq_len_col].drop_duplicates().values:
        
        seq_lens.append(seq_len)
        dataset_size_after_filter = (df_multiple_experiments[df_multiple_experiments[seq_len_col] == seq_len]["dataset_size_after_filter_wrt_input_len"]).drop_duplicates().values
        dataset_sizes_after_filterss.append(list(dataset_size_after_filter)[0])
        
    print(dataset_size)
    print(seq_lens)
    print(dataset_sizes_after_filterss)

    plt.bar(seq_lens, dataset_sizes_after_filterss)
    plt.show()
def plot_bar():
    pass

# %%
dataset_size_after_filtering_sequence_length(df_merge_flores200)
dataset_size_after_filtering_sequence_length(df_merge_wmt14)
# Out:
# 997
# [15, -1, 30, 10]
# [199, 997, 898, 33]
# 3000
# [-1, 30, 15, 10]
# [3000, 2627, 1370, 710]

# %% [markdown]
# ## Separate single and multiple sentence input

# %%
df_merge_flores200_multiple_sentences = df_merge_flores200[df_merge_flores200["dataset_size"] != 1]

display(df_merge_flores200_multiple_sentences)
# Out:
#                            model_name  total_params  use_archer dataset_name  \
# 338                           t5-base     222903552       False    flores200
# 335                           t5-base     222903552       False    flores200
# 401  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 389  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 377  facebook/nllb-200-distilled-600M     615073792       False    flores200
# ..                                ...           ...         ...          ...
# 23         google/switch_16_finetuned           630        True    flores200
# 22         google/switch_16_finetuned           630        True    flores200
# 21         google/switch_16_finetuned           630        True    flores200
# 20         google/switch_16_finetuned           630        True    flores200
# 67             google/switch-base-128          3318       False    flores200
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 338           997                                      199       en       fr
# 335           997                                      199       en       fr
# 401           997                                      997       en       fr
# 389           997                                      898       en       fr
# 377           997                                      898       en       fr
# ..            ...                                      ...      ...      ...
# 23            997                                      997       en       fr
# 22            997                                      997       en       fr
# 21            997                                      997       en       fr
# 20            997                                      997       en       fr
# 67            997                                      997       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 338          32          4             128                    15
# 335          32          4             128                    15
# 401          32          4             128                    -1
# 389          32          4             128                    30
# 377          32          4             128                    30
# ..          ...        ...             ...                   ...
# 23           32          8              20                    -1
# 22           32          4              20                    -1
# 21           32          2              20                    -1
# 20           32          1              20                    -1
# 67           16          4             128                    -1
#
#     tokenizer_padding_setting  sacrebleu  spBleu  chrf  chrfpp  meteor  \
# 338                do_not_pad       47.3      52  68.5    66.8   0.688
# 335         pad_to_max_length       47.3      52  68.5    66.8   0.688
# 401         pad_to_max_length       47.2    51.3  69.4    67.4   0.701
# 389                do_not_pad       47.1    51.2  69.4    67.4   0.701
# 377         pad_to_max_length       47.1    51.2  69.4    67.4   0.701
# ..                        ...        ...     ...   ...     ...     ...
# 23                no_pad_fill       3.73    4.14    22    20.3   0.188
# 22                no_pad_fill       3.71    4.05  21.9    20.3   0.189
# 21                no_pad_fill       3.46    3.74  21.4    19.8   0.183
# 20                no_pad_fill       2.84    3.13    20    18.4   0.168
# 67          pad_to_max_length          0  0.0128   1.6    1.97  0.0223
#
#      gen_len  encoder_latency_s  decoder_latency_s  encoder_throughput  \
# 338     28.8            0.00601            0.00794            7.78e+05
# 335     28.8            0.00622            0.00785            7.51e+05
# 401     40.1             0.0093            0.00596            3.32e+06
# 389     37.6            0.00642            0.00589            4.06e+06
# 377     37.6            0.00629            0.00576            4.15e+06
# ..       ...                ...                ...                 ...
# 23      18.9             0.0817             0.0687            4.19e+05
# 22      18.9             0.0819             0.0656            4.18e+05
# 21      18.9             0.0837             0.0615            4.09e+05
# 20      18.9             0.0894             0.0575            3.83e+05
# 67       127             0.0214             0.0208             1.6e+06
#
#      decoder_throughput device_memory_ratio
# 338            7.22e+05               False
# 335             7.3e+05               False
# 401            6.71e+06               False
# 389            5.74e+06               False
# 377            5.87e+06               False
# ..                  ...                 ...
# 23             2.74e+05               False
# 22             2.88e+05               False
# 21             3.06e+05               False
# 20             3.28e+05               False
# 67             6.09e+06               False
#
# [81 rows x 24 columns]

# %%
df_merge_flores200_single_sentences = df_merge_flores200[df_merge_flores200["dataset_size"] == 1]
display(df_merge_flores200_single_sentences)
# Out:
#                      model_name  total_params  use_archer dataset_name  \
# 299                    t5-large     737668096       False    flores200
# 325                     t5-base     222903552       False    flores200
# 298                    t5-large     737668096       False    flores200
# 295                    t5-large     737668096       False    flores200
# 296                    t5-large     737668096       False    flores200
# 326                     t5-base     222903552       False    flores200
# 294                    t5-large     737668096       False    flores200
# 324                     t5-base     222903552       False    flores200
# 323                     t5-base     222903552       False    flores200
# 297                    t5-large     737668096       False    flores200
# 321                     t5-base     222903552       False    flores200
# 322                     t5-base     222903552       False    flores200
# 15   google/switch_16_finetuned           630        True    flores200
# 14   google/switch_16_finetuned           630        True    flores200
# 9    google/switch_16_finetuned           630        True    flores200
# 13   google/switch_16_finetuned           630        True    flores200
# 12   google/switch_16_finetuned           630        True    flores200
# 8    google/switch_16_finetuned           630        True    flores200
# 10   google/switch_16_finetuned           630        True    flores200
# 11   google/switch_16_finetuned           630        True    flores200
# 5    google/switch_16_finetuned           630        True    flores200
# 7    google/switch_16_finetuned           630        True    flores200
# 6    google/switch_16_finetuned           630        True    flores200
# 345  google/switch_16_finetuned           630        True    flores200
# 4    google/switch_16_finetuned           630        True    flores200
# 49        facebook/nllb-moe-54b     524717009       False    flores200
# 66       google/switch-base-128          3318       False    flores200
# 0    google/switch_16_finetuned           630        True    flores200
# 2    google/switch_16_finetuned           630        True    flores200
# 3    google/switch_16_finetuned           630        True    flores200
# 1    google/switch_16_finetuned           630        True    flores200
# 48        facebook/nllb-moe-54b     524717009       False    flores200
# 52        facebook/nllb-moe-54b     524717009       False    flores200
# 53        facebook/nllb-moe-54b     524717009       False    flores200
# 40        facebook/nllb-moe-54b     524717009       False    flores200
# 41        facebook/nllb-moe-54b     524717009       False    flores200
# 46        facebook/nllb-moe-54b     524717009       False    flores200
# 42        facebook/nllb-moe-54b     524717009       False    flores200
# 51        facebook/nllb-moe-54b     524717009       False    flores200
# 43        facebook/nllb-moe-54b     524717009       False    flores200
# 44        facebook/nllb-moe-54b     524717009       False    flores200
# 50        facebook/nllb-moe-54b     524717009       False    flores200
# 45        facebook/nllb-moe-54b     524717009       False    flores200
# 47        facebook/nllb-moe-54b     524717009       False    flores200
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 299             1                                        1       en       fr
# 325             1                                        1       en       fr
# 298             1                                        1       en       fr
# 295             1                                        1       en       fr
# 296             1                                        1       en       fr
# 326             1                                        1       en       fr
# 294             1                                        1       en       fr
# 324             1                                        1       en       fr
# 323             1                                        1       en       fr
# 297             1                                        1       en       fr
# 321             1                                        1       en       fr
# 322             1                                        1       en       fr
# 15              1                                        1       en       fr
# 14              1                                        1       en       fr
# 9               1                                        1       en       fr
# 13              1                                        1       en       fr
# 12              1                                        1       en       fr
# 8               1                                        1       en       fr
# 10              1                                        1       en       fr
# 11              1                                        1       en       fr
# 5               1                                        1       en       fr
# 7               1                                        1       en       fr
# 6               1                                        1       en       fr
# 345             1                                        1       en       fr
# 4               1                                        1       en       fr
# 49              1                                        1       en       fr
# 66              1                                        1       en       fr
# 0               1                                        1       en       fr
# 2               1                                        1       en       fr
# 3               1                                        1       en       fr
# 1               1                                        1       en       fr
# 48              1                                        1       en       fr
# 52              1                                        1       en       fr
# 53              1                                        1       en       fr
# 40              1                                        1       en       fr
# 41              1                                        1       en       fr
# 46              1                                        1       en       fr
# 42              1                                        1       en       fr
# 51              1                                        1       en       fr
# 43              1                                        1       en       fr
# 44              1                                        1       en       fr
# 50              1                                        1       en       fr
# 45              1                                        1       en       fr
# 47              1                                        1       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 299          32          4             128                    -1
# 325          32          2             128                    -1
# 298          32          2             128                    -1
# 295          32          2             128                    -1
# 296          32          4             128                    -1
# 326          32          4             128                    -1
# 294          32          1             128                    -1
# 324          32          1             128                    -1
# 323          32          4             128                    -1
# 297          32          1             128                    -1
# 321          32          1             128                    -1
# 322          32          2             128                    -1
# 15           32          8             128                    -1
# 14           32          4             128                    -1
# 9            32          2              64                    -1
# 13           32          2             128                    -1
# 12           32          1             128                    -1
# 8            32          1              64                    -1
# 10           32          4              64                    -1
# 11           32          8              64                    -1
# 5            32          2              32                    -1
# 7            32          8              32                    -1
# 6            32          4              32                    -1
# 345          32          1              32                    -1
# 4            32          1              32                    -1
# 49            1          1             128                    -1
# 66           16          4             128                    -1
# 0            32          1              20                    -1
# 2            32          4              20                    -1
# 3            32          8              20                    -1
# 1            32          2              20                    -1
# 48            1          4              64                    -1
# 52           32          8              20                    -1
# 53           32          8              32                    -1
# 40            1          1              20                    -1
# 41            1          2              20                    -1
# 46            1          1              64                    -1
# 42            1          4              20                    -1
# 51            1          4             128                    -1
# 43            1          1              32                    -1
# 44            1          2              32                    -1
# 50            1          2             128                    -1
# 45            1          4              32                    -1
# 47            1          2              64                    -1
#
#     tokenizer_padding_setting  sacrebleu  spBleu  chrf  chrfpp  meteor  \
# 299                do_not_pad       14.5    20.6  53.9    49.5   0.424
# 325                do_not_pad       14.5    20.4  55.1    50.4   0.443
# 298                do_not_pad       14.5    20.6  53.9    49.5   0.424
# 295         pad_to_max_length       14.5    20.6  53.9    49.5   0.424
# 296         pad_to_max_length       14.5    20.6  53.9    49.5   0.424
# 326                do_not_pad       14.5    20.4  55.1    50.4   0.443
# 294         pad_to_max_length       14.5    20.6  53.9    49.5   0.424
# 324                do_not_pad       14.5    20.4  55.1    50.4   0.443
# 323         pad_to_max_length       14.5    20.4  55.1    50.4   0.443
# 297                do_not_pad       14.5    20.6  53.9    49.5   0.424
# 321         pad_to_max_length       14.5    20.4  55.1    50.4   0.443
# 322         pad_to_max_length       14.5    20.4  55.1    50.4   0.443
# 15                no_pad_fill       3.89    4.46  35.8    32.1   0.244
# 14                no_pad_fill       3.89    4.46  35.8    32.1   0.244
# 9                 no_pad_fill       3.74     4.1  34.1    30.7   0.237
# 13                no_pad_fill       3.74     4.1  34.1    30.7   0.237
# 12                no_pad_fill       3.62    2.94  32.6      30   0.227
# 8                 no_pad_fill       3.62    2.94  32.6      30   0.227
# 10                no_pad_fill       3.39    3.77  34.7    30.7   0.213
# 11                no_pad_fill       3.34    3.73  34.2    30.1   0.205
# 5                 no_pad_fill       1.03    1.06  26.7    23.2   0.135
# 7                 no_pad_fill      0.764   0.785  25.8    22.6   0.117
# 6                 no_pad_fill      0.755   0.718    24    20.7   0.109
# 345               no_pad_fill      0.706   0.416  20.8    18.8   0.103
# 4                 no_pad_fill      0.706   0.416  20.8    18.8   0.103
# 49                no_pad_fill      0.423       0    15    11.4       0
# 66          pad_to_max_length      0.308 0.00468  6.22    5.13 0.00801
# 0                 no_pad_fill      0.154  0.0574  13.9      13  0.0721
# 2                 no_pad_fill      0.145  0.0898  18.5      16  0.0641
# 3                 no_pad_fill      0.145  0.0898  18.5      16  0.0641
# 1                 no_pad_fill      0.117  0.0788  15.1      13  0.0481
# 48                no_pad_fill          0       0  8.23    6.17       0
# 52                no_pad_fill          0   0.163  5.73     4.3       0
# 53                no_pad_fill          0   0.329  7.01    5.26       0
# 40                no_pad_fill          0       0  4.24    3.18       0
# 41                no_pad_fill          0       0  3.49    2.61       0
# 46                no_pad_fill          0       0  11.3    8.49       0
# 42                no_pad_fill          0       0  5.09    3.81       0
# 51                no_pad_fill          0       0  12.9    9.68       0
# 43                no_pad_fill          0       0  8.19    6.14       0
# 44                no_pad_fill          0       0  5.23    3.92       0
# 50                no_pad_fill          0       0  12.6    9.43       0
# 45                no_pad_fill          0       0  5.93    4.45       0
# 47                no_pad_fill          0       0  8.04    6.03       0
#
#      gen_len  encoder_latency_s  decoder_latency_s  encoder_throughput  \
# 299       87             0.0136             0.0145            4.42e+03
# 325       84            0.00859            0.00696            6.99e+03
# 298       87             0.0122             0.0139            4.91e+03
# 295       87             0.0119             0.0139            5.06e+03
# 296       87             0.0144              0.014            4.17e+03
# 326       84            0.00864             0.0076            6.95e+03
# 294       87             0.0166             0.0125            3.61e+03
# 324       84            0.00932            0.00679            6.44e+03
# 323       84            0.00964            0.00756            6.22e+03
# 297       87             0.0139             0.0124             4.3e+03
# 321       84            0.00811            0.00687             7.4e+03
# 322       84             0.0118            0.00712            5.07e+03
# 15        71             0.0689             0.0327                 871
# 14        72             0.0599             0.0278               1e+03
# 9         63             0.0722             0.0247                 831
# 13        64             0.0776             0.0228                 773
# 12        64             0.0778             0.0197                 771
# 8         63             0.0726             0.0258                 826
# 10        63             0.0769             0.0269                 781
# 11        63             0.0749             0.0333                 801
# 5         31             0.0743               0.03                 807
# 7         31             0.0717             0.0344                 837
# 6         31             0.0736             0.0287                 815
# 345       31               4.62              0.142                  13
# 4         31             0.0747             0.0254                 804
# 49       128               2.43              0.423                26.4
# 66        32              0.566             0.0442                 106
# 0         19               4.62               0.18                  13
# 2         19             0.0685             0.0475                 876
# 3         19             0.0729             0.0417                 823
# 1         19             0.0761             0.0487                 788
# 48        64               2.51               1.48                25.5
# 52        20                122               7.36               0.523
# 53        32               2.59               2.04                24.7
# 40        20                122               2.48               0.523
# 41        20                122                3.3               0.526
# 46        64               2.42              0.353                26.4
# 42        20               2.43               2.39                26.3
# 51       128               7.42               1.15                8.63
# 43        32               2.43              0.376                26.4
# 44        32               2.59              0.506                24.7
# 50       128               6.31              0.638                10.1
# 45        32               2.43               1.59                26.4
# 47        64               2.42              0.743                26.4
#
#      decoder_throughput device_memory_ratio
# 299               6e+03               False
# 325            1.21e+04               False
# 298            6.25e+03               False
# 295            6.26e+03               False
# 296            6.22e+03               False
# 326            1.11e+04               False
# 294            6.98e+03               False
# 324            1.24e+04               False
# 323            1.11e+04               False
# 297            7.03e+03               False
# 321            1.22e+04               False
# 322            1.18e+04               False
# 15             2.17e+03               False
# 14             2.59e+03               False
# 9              2.55e+03               False
# 13             2.81e+03               False
# 12             3.24e+03               False
# 8              2.45e+03               False
# 10             2.34e+03               False
# 11             1.89e+03               False
# 5              1.03e+03               False
# 7                   901               False
# 6              1.08e+03               False
# 345                 219                 0.1
# 4              1.22e+03               False
# 49                  302               False
# 66                  725               False
# 0                   106               False
# 2                   400               False
# 3                   456               False
# 1                   390               False
# 48                 43.3               False
# 52                 2.72               False
# 53                 15.7               False
# 40                 8.07               False
# 41                 6.05               False
# 46                  181               False
# 42                 8.37               False
# 51                  111               False
# 43                 85.1               False
# 44                 63.2               False
# 50                  201               False
# 45                 20.2               False
# 47                 86.2               False

# %% [markdown]
# Some first insight:
# We initially padded our tokenizers if sentence length is short.
# Then, from our first experimentation, notice that there is a trend in the column max_length and beam size.
# We wondered whether this has to do with padding so we decided to test out with it by adding a new hyperparameter: "no_pad_fill"

# %%
df_merge_wmt14_multiple_sentences = df_merge_wmt14[df_merge_wmt14["dataset_size"] != 1]
df_merge_wmt14_multiple_sentences
# Out:
#                            model_name  total_params  use_archer dataset_name  \
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 172  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 184  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 181  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# ..                                ...           ...         ...          ...
# 130                           t5-base     222903552       False        wmt14
# 133                           t5-base     222903552       False        wmt14
# 347        google/switch_16_finetuned           630        True        wmt14
# 404        google/switch_16_finetuned           630        True        wmt14
# 35             google/switch-base-128          3318       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 196          3000                                     3000       en       fr
# 208          3000                                     3000       en       fr
# 172          3000                                     2627       en       fr
# 184          3000                                     2627       en       fr
# 181          3000                                     2627       en       fr
# ..            ...                                      ...      ...      ...
# 130          3000                                     1370       en       fr
# 133          3000                                     1370       en       fr
# 347          3000                                     3000       en       fr
# 404          3000                                     3000       en       fr
# 35           3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 196          32          4             128                    -1
# 208          32          4             128                    -1
# 172          32          4             128                    30
# 184          32          4             128                    30
# 181          32          4              64                    30
# ..          ...        ...             ...                   ...
# 130          32          1             128                    15
# 133          32          1             128                    15
# 347          32          1              32                    -1
# 404          32          1              32                    -1
# 35           16          4             128                    -1
#
#     tokenizer_padding_setting  sacrebleu  spBleu  chrf  chrfpp  meteor  \
# 196         pad_to_max_length       34.5      39  59.3    57.1   0.593
# 208                do_not_pad       34.5      39  59.3    57.1   0.593
# 172         pad_to_max_length       34.4    38.9  58.8    56.6   0.591
# 184                do_not_pad       34.4    38.9  58.8    56.6   0.591
# 181                do_not_pad       34.4    38.9  58.7    56.6   0.591
# ..                        ...        ...     ...   ...     ...     ...
# 130         pad_to_max_length       30.9    35.6  55.5    53.4   0.552
# 133                do_not_pad       30.9    35.6  55.5    53.4   0.552
# 347               no_pad_fill       6.12    7.25  27.4    25.4   0.261
# 404               no_pad_fill       6.12    7.25  27.4    25.4   0.261
# 35          pad_to_max_length          0 0.00625  1.53    1.97  0.0277
#
#      gen_len  encoder_latency_s  decoder_latency_s  encoder_throughput  \
# 196     35.8             0.0105            0.00578            7.94e+06
# 208     35.8             0.0112            0.00598            7.49e+06
# 172     30.6            0.00635            0.00596            9.84e+06
# 184     30.6            0.00675            0.00589            9.26e+06
# 181     30.6            0.00627            0.00583            9.97e+06
# ..       ...                ...                ...                 ...
# 130     22.3            0.00586            0.00775            4.67e+06
# 133     22.3            0.00588            0.00764            4.65e+06
# 347     26.3              0.101             0.0628            9.38e+05
# 404     26.3              0.102             0.0638            9.33e+05
# 35       127             0.0226             0.0207            4.21e+06
#
#      decoder_throughput device_memory_ratio
# 196            1.86e+07               False
# 208             1.8e+07               False
# 172            1.35e+07               False
# 184            1.37e+07               False
# 181            1.38e+07               False
# ..                  ...                 ...
# 130            3.94e+06               False
# 133               4e+06               False
# 347            1.26e+06                 0.9
# 404            1.24e+06                 0.3
# 35             1.84e+07               False
#
# [82 rows x 24 columns]

# %% [markdown]
# Also, for latency and throughput, we first recorded it outside model.generate(). but, in order to truly analyse the inference speed, it is better to break down into the encoder and decoder speed.
# The other reason is that we want to normalise this metric, since working with variable inputs means that some batches may finish faster than others - it is not correct to compare inference speed of sentence length 10 vs another sample with sentence length 50. hence, we need to normalise it.
# To do that, we divide the latency for encoder by the number of tokens.

# %%
df_merge_wmt14_single_sentence = df_merge_wmt14[df_merge_wmt14["dataset_size"] == 1].drop(["sacrebleu", "spBleu", "chrf" ,'chrfpp', 'meteor'], axis=1)
df_merge_wmt14_single_sentence = df_merge_wmt14_single_sentence.sort_values(by=['encoder_latency_s'], ascending=False)
df_merge_wmt14_single_sentence
# Out:
#                            model_name  total_params  use_archer dataset_name  \
# 54              facebook/nllb-moe-54b     524717009       False        wmt14
# 59              facebook/nllb-moe-54b     524717009       False        wmt14
# 318             facebook/nllb-moe-54b     524717009        True        wmt14
# 68              facebook/nllb-moe-54b     524717009        True        wmt14
# 56              facebook/nllb-moe-54b     524717009       False        wmt14
# ..                                ...           ...         ...          ...
# 252  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 240  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 276  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 256  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 264  facebook/nllb-200-distilled-600M     615073792       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 54              1                                        1       en       fr
# 59              1                                        1       en       fr
# 318             1                                        1       en       fr
# 68              1                                        1       en       fr
# 56              1                                        1       en       fr
# ..            ...                                      ...      ...      ...
# 252             1                                        1       en       fr
# 240             1                                        1       en       fr
# 276             1                                        1       en       fr
# 256             1                                        1       en       fr
# 264             1                                        1       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 54            1          1              20                    -1
# 59            1          4              32                    -1
# 318          32          1              32                    -1
# 68           32          1              32                    -1
# 56            1          4              20                    -1
# ..          ...        ...             ...                   ...
# 252          32          2              64                    30
# 240          32          2              64                    30
# 276          32          2              64                    -1
# 256          32          4             128                    30
# 264          32          2              64                    -1
#
#     tokenizer_padding_setting  gen_len  encoder_latency_s  decoder_latency_s  \
# 54                no_pad_fill       20               63.2               2.49
# 59                no_pad_fill       32               63.1               3.49
# 318               no_pad_fill       32               62.7               1.92
# 68                no_pad_fill       32               62.4               1.91
# 56                no_pad_fill       20                 18               1.15
# ..                        ...      ...                ...                ...
# 252                do_not_pad       20            0.00745            0.00606
# 240         pad_to_max_length       20            0.00738            0.00599
# 276                do_not_pad       20            0.00735            0.00603
# 256                do_not_pad       20            0.00657             0.0062
# 264         pad_to_max_length       20            0.00629            0.00599
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 54                0.332                8.04               False
# 59                0.333                9.16               False
# 318               0.335                16.7                 0.6
# 68                0.336                16.7                 0.6
# 56                 1.17                17.5               False
# ..                  ...                 ...                 ...
# 252            2.01e+03             3.3e+03               False
# 240            2.03e+03            3.34e+03               False
# 276            2.04e+03            3.32e+03               False
# 256            2.28e+03            3.22e+03               False
# 264            2.38e+03            3.34e+03               False
#
# [97 rows x 19 columns]

# %% [markdown]
# ### Percentage of outputs for single and multiple

# %%
# WMT14
total_len_wmt_experiments = len(df_merge_wmt14_single_sentence) + len(df_merge_wmt14_multiple_sentences)
assert(total_len_wmt_experiments ==len(df_merge_wmt14))
total_len_wmt_experiments
# Out:
# 179

# %%
total_len_flores_experiments = len(df_merge_flores200_single_sentences) + len(df_merge_flores200_multiple_sentences)
assert(total_len_flores_experiments ==len(df_merge_flores200))
total_len_flores_experiments
# Out:
# 124

# %% [markdown]
# ### Brainstorming

# %% [markdown]
# I kept the max_gen_length constant, since I wasn't sure if it was a useful metric for machine translation (at least for my purposes here, since the maximum number of tokens a sentence can have is around 80 or something like that), but i could be wrong. Yesterday I showed you that max_gen_length did slightly better than 256. My speculation that maybe one of the results' generation got truncuated from the decoder, but that does not mean the translation is better
#
# Oh so, we wanted to investigate the low gen_length, so we wanted to check the padding if it destroys accuracy. in theory, it shouldnt. we see from our experiments that it doesnt.

# %% [markdown]
# # Analysis

# %% [markdown]
# Find the best parameter for each other fixed one, with max_input_seq_len being -1

# %%
df_merge_all_temp = copy.deepcopy(df_merge_all)
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["max_input_seq_length"] == -1] 
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["dataset_size"] != 1] 
df_merge_all_temp = df_merge_all_temp.sort_values("sacrebleu", ascending=False)

# %%
df_merge_all_temp
# Out:
#                            model_name  total_params  use_archer dataset_name  \
# 401  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 398  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 400  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 302                          t5-large     737668096       False    flores200
# 305                          t5-large     737668096       False    flores200
# 397  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 301                          t5-large     737668096       False    flores200
# 304                          t5-large     737668096       False    flores200
# 399  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 329                           t5-base     222903552       False    flores200
# 332                           t5-base     222903552       False    flores200
# 331                           t5-base     222903552       False    flores200
# 328                           t5-base     222903552       False    flores200
# 396  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 303                          t5-large     737668096       False    flores200
# 300                          t5-large     737668096       False    flores200
# 330                           t5-base     222903552       False    flores200
# 327                           t5-base     222903552       False    flores200
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 207  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 195  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 206  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 194  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 205  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 193  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 192  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 204  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 89                           t5-large     737668096       False        wmt14
# 92                           t5-large     737668096       False        wmt14
# 91                           t5-large     737668096       False        wmt14
# 88                           t5-large     737668096       False        wmt14
# 191  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 203  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 87                           t5-large     737668096       False        wmt14
# 90                           t5-large     737668096       False        wmt14
# 129                           t5-base     222903552       False        wmt14
# 126                           t5-base     222903552       False        wmt14
# 125                           t5-base     222903552       False        wmt14
# 128                           t5-base     222903552       False        wmt14
# 124                           t5-base     222903552       False        wmt14
# 127                           t5-base     222903552       False        wmt14
# 30         google/switch_16_finetuned           630        True    flores200
# 29         google/switch_16_finetuned           630        True    flores200
# 32         google/switch_16_finetuned           630        True    flores200
# 28         google/switch_16_finetuned           630        True    flores200
# 31         google/switch_16_finetuned           630        True    flores200
# 27         google/switch_16_finetuned           630        True    flores200
# 26         google/switch_16_finetuned           630        True    flores200
# 25         google/switch_16_finetuned           630        True    flores200
# 24         google/switch_16_finetuned           630        True    flores200
# 404        google/switch_16_finetuned           630        True        wmt14
# 347        google/switch_16_finetuned           630        True        wmt14
# 23         google/switch_16_finetuned           630        True    flores200
# 22         google/switch_16_finetuned           630        True    flores200
# 21         google/switch_16_finetuned           630        True    flores200
# 20         google/switch_16_finetuned           630        True    flores200
# 67             google/switch-base-128          3318       False    flores200
# 35             google/switch-base-128          3318       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 401           997                                      997       en       fr
# 398           997                                      997       en       fr
# 400           997                                      997       en       fr
# 302           997                                      997       en       fr
# 305           997                                      997       en       fr
# 397           997                                      997       en       fr
# 301           997                                      997       en       fr
# 304           997                                      997       en       fr
# 399           997                                      997       en       fr
# 329           997                                      997       en       fr
# 332           997                                      997       en       fr
# 331           997                                      997       en       fr
# 328           997                                      997       en       fr
# 396           997                                      997       en       fr
# 303           997                                      997       en       fr
# 300           997                                      997       en       fr
# 330           997                                      997       en       fr
# 327           997                                      997       en       fr
# 208          3000                                     3000       en       fr
# 196          3000                                     3000       en       fr
# 207          3000                                     3000       en       fr
# 195          3000                                     3000       en       fr
# 206          3000                                     3000       en       fr
# 194          3000                                     3000       en       fr
# 205          3000                                     3000       en       fr
# 193          3000                                     3000       en       fr
# 192          3000                                     3000       en       fr
# 204          3000                                     3000       en       fr
# 89           3000                                     3000       en       fr
# 92           3000                                     3000       en       fr
# 91           3000                                     3000       en       fr
# 88           3000                                     3000       en       fr
# 191          3000                                     3000       en       fr
# 203          3000                                     3000       en       fr
# 87           3000                                     3000       en       fr
# 90           3000                                     3000       en       fr
# 129          3000                                     3000       en       fr
# 126          3000                                     3000       en       fr
# 125          3000                                     3000       en       fr
# 128          3000                                     3000       en       fr
# 124          3000                                     3000       en       fr
# 127          3000                                     3000       en       fr
# 30            997                                      997       en       fr
# 29            997                                      997       en       fr
# 32            997                                      997       en       fr
# 28            997                                      997       en       fr
# 31            997                                      997       en       fr
# 27            997                                      997       en       fr
# 26            997                                      997       en       fr
# 25            997                                      997       en       fr
# 24            997                                      997       en       fr
# 404          3000                                     3000       en       fr
# 347          3000                                     3000       en       fr
# 23            997                                      997       en       fr
# 22            997                                      997       en       fr
# 21            997                                      997       en       fr
# 20            997                                      997       en       fr
# 67            997                                      997       en       fr
# 35           3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 401          32          4             128                    -1
# 398          32          4              64                    -1
# 400          32          2             128                    -1
# 302          32          4             128                    -1
# 305          32          4             128                    -1
# 397          32          2              64                    -1
# 301          32          2             128                    -1
# 304          32          2             128                    -1
# 399          32          1             128                    -1
# 329          32          4             128                    -1
# 332          32          4             128                    -1
# 331          32          2             128                    -1
# 328          32          2             128                    -1
# 396          32          1              64                    -1
# 303          32          1             128                    -1
# 300          32          1             128                    -1
# 330          32          1             128                    -1
# 327          32          1             128                    -1
# 208          32          4             128                    -1
# 196          32          4             128                    -1
# 207          32          2             128                    -1
# 195          32          2             128                    -1
# 206          32          1             128                    -1
# 194          32          1             128                    -1
# 205          32          4              64                    -1
# 193          32          4              64                    -1
# 192          32          2              64                    -1
# 204          32          2              64                    -1
# 89           32          4             128                    -1
# 92           32          4             128                    -1
# 91           32          2             128                    -1
# 88           32          2             128                    -1
# 191          32          1              64                    -1
# 203          32          1              64                    -1
# 87           32          1             128                    -1
# 90           32          1             128                    -1
# 129          32          4             128                    -1
# 126          32          4             128                    -1
# 125          32          2             128                    -1
# 128          32          2             128                    -1
# 124          32          1             128                    -1
# 127          32          1             128                    -1
# 30           32          8              64                    -1
# 29           32          4              64                    -1
# 32           32          2             128                    -1
# 28           32          2              64                    -1
# 31           32          1             128                    -1
# 27           32          1              64                    -1
# 26           32          8              32                    -1
# 25           32          4              32                    -1
# 24           32          2              32                    -1
# 404          32          1              32                    -1
# 347          32          1              32                    -1
# 23           32          8              20                    -1
# 22           32          4              20                    -1
# 21           32          2              20                    -1
# 20           32          1              20                    -1
# 67           16          4             128                    -1
# 35           16          4             128                    -1
#
#     tokenizer_padding_setting  sacrebleu  spBleu  chrf  chrfpp  meteor  \
# 401         pad_to_max_length       47.2    51.3  69.4    67.4   0.701
# 398         pad_to_max_length       46.7    50.7  68.9    66.9   0.697
# 400         pad_to_max_length       46.6    50.6  68.9    66.9   0.696
# 302         pad_to_max_length       46.1    50.7  68.7    66.7   0.684
# 305                do_not_pad       46.1    50.7  68.7    66.7   0.684
# 397         pad_to_max_length       46.1    50.1  68.4    66.5   0.693
# 301         pad_to_max_length       45.5    49.9  68.3    66.3   0.681
# 304                do_not_pad       45.5    49.9  68.3    66.3   0.681
# 399         pad_to_max_length         45    48.8  67.6    65.6   0.682
# 329         pad_to_max_length         45    49.5  67.9    65.9   0.677
# 332                do_not_pad         45    49.5  67.9    65.9   0.677
# 331                do_not_pad       44.9    49.3  67.8    65.8   0.675
# 328         pad_to_max_length       44.9    49.3  67.8    65.8   0.675
# 396         pad_to_max_length       44.6    48.3  67.1    65.2   0.678
# 303                do_not_pad       44.5    48.6  67.3    65.4   0.673
# 300         pad_to_max_length       44.5    48.6  67.3    65.4   0.673
# 330                do_not_pad       43.8      48  66.9    64.9   0.667
# 327         pad_to_max_length       43.8      48  66.9    64.9   0.667
# 208                do_not_pad       34.5      39  59.3    57.1   0.593
# 196         pad_to_max_length       34.5      39  59.3    57.1   0.593
# 207                do_not_pad       34.4    38.7  59.1    56.9   0.591
# 195         pad_to_max_length       34.4    38.7  59.1    56.9   0.591
# 206                do_not_pad       33.6    37.7  58.5    56.3   0.585
# 194         pad_to_max_length       33.6    37.7  58.5    56.3   0.585
# 205                do_not_pad       33.2    37.5  57.6    55.4   0.583
# 193         pad_to_max_length       33.2    37.5  57.6    55.4   0.583
# 192         pad_to_max_length         33    37.1  57.4    55.2   0.582
# 204                do_not_pad         33    37.1  57.4    55.2   0.582
# 89          pad_to_max_length       32.8    37.8  58.7    56.3    0.58
# 92                 do_not_pad       32.8    37.8  58.7    56.3    0.58
# 91                 do_not_pad       32.6    37.6  58.5    56.2   0.579
# 88          pad_to_max_length       32.6    37.6  58.5    56.2   0.579
# 191         pad_to_max_length       32.4    36.3  56.8    54.7   0.577
# 203                do_not_pad       32.4    36.3  56.8    54.7   0.577
# 87          pad_to_max_length       32.1    36.8  58.1    55.8   0.574
# 90                 do_not_pad       32.1    36.8  58.1    55.8   0.574
# 129                do_not_pad         32      37  58.1    55.7   0.573
# 126         pad_to_max_length         32      37  58.1    55.7   0.573
# 125         pad_to_max_length       31.8    36.7  57.9    55.6   0.572
# 128                do_not_pad       31.8    36.7  57.9    55.6   0.572
# 124         pad_to_max_length       31.2    35.9  57.4      55   0.564
# 127                do_not_pad       31.2    35.9  57.4      55   0.564
# 30                no_pad_fill       11.8    14.2  39.3    36.5    0.35
# 29                no_pad_fill       11.6    13.9    39    36.2    0.35
# 32                no_pad_fill       11.5    13.3  38.5    35.9   0.348
# 28                no_pad_fill       11.1    12.9  37.9    35.3   0.343
# 31                no_pad_fill       10.2    11.9  36.5    33.9   0.329
# 27                no_pad_fill       9.89    11.5    36    33.5   0.325
# 26                no_pad_fill       8.07    9.51  31.1    28.9   0.278
# 25                no_pad_fill       7.95    9.29  30.8    28.6   0.277
# 24                no_pad_fill       7.58    8.63  30.3    28.1    0.27
# 404               no_pad_fill       6.12    7.25  27.4    25.4   0.261
# 347               no_pad_fill       6.12    7.25  27.4    25.4   0.261
# 23                no_pad_fill       3.73    4.14    22    20.3   0.188
# 22                no_pad_fill       3.71    4.05  21.9    20.3   0.189
# 21                no_pad_fill       3.46    3.74  21.4    19.8   0.183
# 20                no_pad_fill       2.84    3.13    20    18.4   0.168
# 67          pad_to_max_length          0  0.0128   1.6    1.97  0.0223
# 35          pad_to_max_length          0 0.00625  1.53    1.97  0.0277
#
#      gen_len  encoder_latency_s  decoder_latency_s  encoder_throughput  \
# 401     40.1             0.0093            0.00596            3.32e+06
# 398     39.7             0.0072            0.00591            4.29e+06
# 400     39.8            0.00553             0.0059            5.59e+06
# 302     45.8             0.0112             0.0238            3.04e+06
# 305     45.8             0.0113             0.0238            3.03e+06
# 397     39.4            0.00553            0.00585            5.59e+06
# 301     45.4             0.0111             0.0151            3.08e+06
# 304     45.4             0.0112             0.0153            3.04e+06
# 399       39            0.00555            0.00603            5.57e+06
# 329     45.7            0.00612            0.00885            5.59e+06
# 332     45.7            0.00615            0.00873            5.56e+06
# 331     45.6             0.0062            0.00771            5.52e+06
# 328     45.6            0.00593            0.00755            5.77e+06
# 396     38.6            0.00549            0.00598            5.63e+06
# 303     44.9             0.0114             0.0148               3e+06
# 300     44.9             0.0113             0.0148            3.03e+06
# 330     44.9            0.00652            0.00782            5.25e+06
# 327     44.9            0.00604            0.00768            5.66e+06
# 208     35.8             0.0112            0.00598            7.49e+06
# 196     35.8             0.0105            0.00578            7.94e+06
# 207     35.6            0.00558            0.00586             1.5e+07
# 195     35.6            0.00575            0.00588            1.46e+07
# 206       35            0.00556             0.0059            1.51e+07
# 194       35            0.00605            0.00596            1.38e+07
# 205     34.4             0.0083            0.00594            1.01e+07
# 193     34.4            0.00797            0.00579            1.05e+07
# 192     34.2            0.00587            0.00578            1.43e+07
# 204     34.2            0.00607            0.00588            1.38e+07
# 89        40             0.0121             0.0235            7.88e+06
# 92        40             0.0119             0.0233            7.97e+06
# 91      39.8             0.0109              0.016            8.71e+06
# 88      39.8             0.0112             0.0164            8.51e+06
# 191     33.8            0.00577            0.00579            1.45e+07
# 203     33.8            0.00566            0.00585            1.48e+07
# 87      39.3             0.0109              0.015            8.71e+06
# 90      39.3              0.011              0.015            8.64e+06
# 129     40.1            0.00628            0.00933            1.51e+07
# 126     40.1            0.00634            0.00935             1.5e+07
# 125     39.9            0.00658            0.00775            1.44e+07
# 128     39.9            0.00626            0.00762            1.52e+07
# 124     39.5            0.00617            0.00748            1.54e+07
# 127     39.5            0.00629             0.0076            1.51e+07
# 30      41.7             0.0814             0.0723             4.2e+05
# 29      41.4             0.0816             0.0647            4.19e+05
# 32      42.9             0.0816             0.0509            4.19e+05
# 28        41              0.082             0.0589            4.17e+05
# 31      44.6             0.0816             0.0429            4.19e+05
# 27      41.8             0.0826             0.0529            4.14e+05
# 26      29.6             0.0814               0.07             4.2e+05
# 25      29.5             0.0818             0.0664            4.18e+05
# 24      29.5             0.0824             0.0627            4.15e+05
# 404     26.3              0.102             0.0638            9.33e+05
# 347     26.3              0.101             0.0628            9.38e+05
# 23      18.9             0.0817             0.0687            4.19e+05
# 22      18.9             0.0819             0.0656            4.18e+05
# 21      18.9             0.0837             0.0615            4.09e+05
# 20      18.9             0.0894             0.0575            3.83e+05
# 67       127             0.0214             0.0208             1.6e+06
# 35       127             0.0226             0.0207            4.21e+06
#
#      decoder_throughput device_memory_ratio
# 401            6.71e+06               False
# 398            6.69e+06               False
# 400            6.72e+06               False
# 302            1.92e+06               False
# 305            1.92e+06               False
# 397            6.71e+06               False
# 301            2.99e+06               False
# 304            2.96e+06               False
# 399            6.44e+06               False
# 329            5.15e+06               False
# 332            5.22e+06               False
# 331            5.89e+06               False
# 328            6.02e+06               False
# 396            6.43e+06               False
# 303            3.03e+06               False
# 300            3.02e+06               False
# 330            5.73e+06               False
# 327            5.83e+06               False
# 208             1.8e+07               False
# 196            1.86e+07               False
# 207            1.82e+07               False
# 195            1.81e+07               False
# 206            1.78e+07               False
# 194            1.76e+07               False
# 205            1.74e+07               False
# 193            1.78e+07               False
# 192            1.78e+07               False
# 204            1.75e+07               False
# 89              5.1e+06               False
# 92             5.15e+06               False
# 91             7.47e+06               False
# 88             7.27e+06               False
# 191            1.75e+07               False
# 203            1.73e+07               False
# 87             7.85e+06               False
# 90             7.85e+06               False
# 129            1.29e+07               False
# 126            1.29e+07               False
# 125            1.54e+07               False
# 128            1.57e+07               False
# 124            1.58e+07               False
# 127            1.56e+07               False
# 30             5.75e+05               False
# 29             6.38e+05               False
# 32             8.41e+05               False
# 28             6.95e+05               False
# 31             1.04e+06               False
# 27             7.88e+05               False
# 26             4.22e+05               False
# 25             4.43e+05               False
# 24              4.7e+05               False
# 404            1.24e+06                 0.3
# 347            1.26e+06                 0.9
# 23             2.74e+05               False
# 22             2.88e+05               False
# 21             3.06e+05               False
# 20             3.28e+05               False
# 67             6.09e+06               False
# 35             1.84e+07               False

# %%
metrics = ["sacrebleu", "spBleu", "chrf", "chrfpp", "meteor"]
dataset_names = ["wmt14", "flores200"]
for ds_name in dataset_names:
    print("-------")
    print(ds_name)
    
    for metric in metrics:
    
        df_merge_all_temp_ds = df_merge_all_temp[df_merge_all_temp["dataset_name"] == ds_name] 
        display(df_merge_all_temp_ds.head(3))
        df_merge_all_temp_ds = df_merge_all_temp_ds.sort_values("sacrebleu", ascending=False)
        display(df_merge_all_temp_ds.head(3))
        df_merge_all_temp_ds = df_merge_all_temp_ds.sort_values("spBleu", ascending=False)
        display(df_merge_all_temp_ds.head(3))
        df_merge_all_temp_ds = df_merge_all_temp_ds.sort_values("chrf", ascending=False)
        display(df_merge_all_temp_ds.head(3))
        df_merge_all_temp_ds = df_merge_all_temp_ds.sort_values("chrfpp", ascending=False)
        display(df_merge_all_temp_ds.head(3))
        
        df_merge_all_temp_ds = df_merge_all_temp_ds.sort_values("meteor", ascending=False)
        display(df_merge_all_temp_ds[df_merge_all_temp_ds["beam_size"] == 1].head(10))
# Out:
# -------
# wmt14
#                            model_name  total_params  use_archer dataset_name  \
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 207  facebook/nllb-200-distilled-600M     615073792       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 208          3000                                     3000       en       fr
# 196          3000                                     3000       en       fr
# 207          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 208          32          4             128                    -1
# 196          32          4             128                    -1
# 207          32          2             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 208                do_not_pad  34.515130  39.005513  59.290880  57.095659
# 196         pad_to_max_length  34.515130  39.005513  59.290880  57.095659
# 207                do_not_pad  34.356154  38.659230  59.102346  56.915936
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 208  0.592607  35.789000           0.011184           0.005976
# 196  0.592607  35.789000           0.010550           0.005781
# 207  0.590741  35.575667           0.005580           0.005861
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 208           7491695.0        1.796747e+07               False
# 196           7941942.0        1.857388e+07               False
# 207          15014834.0        1.820873e+07               False
#                            model_name  total_params  use_archer dataset_name  \
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 207  facebook/nllb-200-distilled-600M     615073792       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 208          3000                                     3000       en       fr
# 196          3000                                     3000       en       fr
# 207          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 208          32          4             128                    -1
# 196          32          4             128                    -1
# 207          32          2             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 208                do_not_pad  34.515130  39.005513  59.290880  57.095659
# 196         pad_to_max_length  34.515130  39.005513  59.290880  57.095659
# 207                do_not_pad  34.356154  38.659230  59.102346  56.915936
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 208  0.592607  35.789000           0.011184           0.005976
# 196  0.592607  35.789000           0.010550           0.005781
# 207  0.590741  35.575667           0.005580           0.005861
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 208           7491695.0        1.796747e+07               False
# 196           7941942.0        1.857388e+07               False
# 207          15014834.0        1.820873e+07               False
#                            model_name  total_params  use_archer dataset_name  \
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 207  facebook/nllb-200-distilled-600M     615073792       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 208          3000                                     3000       en       fr
# 196          3000                                     3000       en       fr
# 207          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 208          32          4             128                    -1
# 196          32          4             128                    -1
# 207          32          2             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 208                do_not_pad  34.515130  39.005513  59.290880  57.095659
# 196         pad_to_max_length  34.515130  39.005513  59.290880  57.095659
# 207                do_not_pad  34.356154  38.659230  59.102346  56.915936
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 208  0.592607  35.789000           0.011184           0.005976
# 196  0.592607  35.789000           0.010550           0.005781
# 207  0.590741  35.575667           0.005580           0.005861
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 208           7491695.0        1.796747e+07               False
# 196           7941942.0        1.857388e+07               False
# 207          15014834.0        1.820873e+07               False
#                            model_name  total_params  use_archer dataset_name  \
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 207  facebook/nllb-200-distilled-600M     615073792       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 208          3000                                     3000       en       fr
# 196          3000                                     3000       en       fr
# 207          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 208          32          4             128                    -1
# 196          32          4             128                    -1
# 207          32          2             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 208                do_not_pad  34.515130  39.005513  59.290880  57.095659
# 196         pad_to_max_length  34.515130  39.005513  59.290880  57.095659
# 207                do_not_pad  34.356154  38.659230  59.102346  56.915936
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 208  0.592607  35.789000           0.011184           0.005976
# 196  0.592607  35.789000           0.010550           0.005781
# 207  0.590741  35.575667           0.005580           0.005861
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 208           7491695.0        1.796747e+07               False
# 196           7941942.0        1.857388e+07               False
# 207          15014834.0        1.820873e+07               False
#                            model_name  total_params  use_archer dataset_name  \
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 207  facebook/nllb-200-distilled-600M     615073792       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 208          3000                                     3000       en       fr
# 196          3000                                     3000       en       fr
# 207          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 208          32          4             128                    -1
# 196          32          4             128                    -1
# 207          32          2             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 208                do_not_pad  34.515130  39.005513  59.290880  57.095659
# 196         pad_to_max_length  34.515130  39.005513  59.290880  57.095659
# 207                do_not_pad  34.356154  38.659230  59.102346  56.915936
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 208  0.592607  35.789000           0.011184           0.005976
# 196  0.592607  35.789000           0.010550           0.005781
# 207  0.590741  35.575667           0.005580           0.005861
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 208           7491695.0        1.796747e+07               False
# 196           7941942.0        1.857388e+07               False
# 207          15014834.0        1.820873e+07               False
#                            model_name  total_params  use_archer dataset_name  \
# 206  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 194  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 203  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 191  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 90                           t5-large     737668096       False        wmt14
# 87                           t5-large     737668096       False        wmt14
# 127                           t5-base     222903552       False        wmt14
# 124                           t5-base     222903552       False        wmt14
# 402        google/switch_16_finetuned           630        True        wmt14
# 346        google/switch_16_finetuned           630        True        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 206          3000                                     3000       en       fr
# 194          3000                                     3000       en       fr
# 203          3000                                     3000       en       fr
# 191          3000                                     3000       en       fr
# 90           3000                                     3000       en       fr
# 87           3000                                     3000       en       fr
# 127          3000                                     3000       en       fr
# 124          3000                                     3000       en       fr
# 402          3000                                     3000       en       fr
# 346          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 206          32          1             128                    -1
# 194          32          1             128                    -1
# 203          32          1              64                    -1
# 191          32          1              64                    -1
# 90           32          1             128                    -1
# 87           32          1             128                    -1
# 127          32          1             128                    -1
# 124          32          1             128                    -1
# 402          32          1              32                    -1
# 346          32          1              32                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 206                do_not_pad  33.636513  37.724404  58.479601  56.319604
# 194         pad_to_max_length  33.636513  37.724404  58.479601  56.319604
# 203                do_not_pad  32.398901  36.274831  56.829105  54.724418
# 191         pad_to_max_length  32.398901  36.274831  56.829105  54.724418
# 90                 do_not_pad  32.085684  36.828827  58.115874  55.788274
# 87          pad_to_max_length  32.085684  36.828827  58.115874  55.788274
# 127                do_not_pad  31.235333  35.937655  57.400627  55.032425
# 124         pad_to_max_length  31.235333  35.937655  57.400627  55.032425
# 402               no_pad_fill   6.121815   7.247041  27.393845  25.376740
# 346               no_pad_fill   6.121815   7.247041  27.393845  25.376740
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 206  0.585461  35.034000           0.005564           0.005899
# 194  0.585461  35.034000           0.006055           0.005961
# 203  0.576788  33.765000           0.005660           0.005848
# 191  0.576788  33.765000           0.005766           0.005786
# 90   0.574383  39.319000           0.011003           0.015031
# 87   0.574383  39.319000           0.010922           0.015032
# 127  0.564298  39.499667           0.006290           0.007605
# 124  0.564298  39.499667           0.006166           0.007485
# 402  0.261448  26.332000           0.101974           0.063782
# 346  0.261448  26.332000           0.101428           0.062760
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 206         15059168.00        1.781566e+07               False
# 194         13837881.00        1.763131e+07               False
# 203         14803990.00        1.732245e+07               False
# 191         14530785.00        1.750658e+07               False
# 90           8644206.00        7.847833e+06               False
# 87           8708322.00        7.847112e+06               False
# 127         15119876.00        1.558253e+07               False
# 124         15424278.00        1.583257e+07               False
# 402           932672.56        1.238524e+06                 0.3
# 346           937687.10        1.258701e+06                 0.9
#                            model_name  total_params  use_archer dataset_name  \
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 207  facebook/nllb-200-distilled-600M     615073792       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 208          3000                                     3000       en       fr
# 196          3000                                     3000       en       fr
# 207          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 208          32          4             128                    -1
# 196          32          4             128                    -1
# 207          32          2             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 208                do_not_pad  34.515130  39.005513  59.290880  57.095659
# 196         pad_to_max_length  34.515130  39.005513  59.290880  57.095659
# 207                do_not_pad  34.356154  38.659230  59.102346  56.915936
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 208  0.592607  35.789000           0.011184           0.005976
# 196  0.592607  35.789000           0.010550           0.005781
# 207  0.590741  35.575667           0.005580           0.005861
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 208           7491695.0        1.796747e+07               False
# 196           7941942.0        1.857388e+07               False
# 207          15014834.0        1.820873e+07               False
#                            model_name  total_params  use_archer dataset_name  \
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 207  facebook/nllb-200-distilled-600M     615073792       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 208          3000                                     3000       en       fr
# 196          3000                                     3000       en       fr
# 207          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 208          32          4             128                    -1
# 196          32          4             128                    -1
# 207          32          2             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 208                do_not_pad  34.515130  39.005513  59.290880  57.095659
# 196         pad_to_max_length  34.515130  39.005513  59.290880  57.095659
# 207                do_not_pad  34.356154  38.659230  59.102346  56.915936
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 208  0.592607  35.789000           0.011184           0.005976
# 196  0.592607  35.789000           0.010550           0.005781
# 207  0.590741  35.575667           0.005580           0.005861
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 208           7491695.0        1.796747e+07               False
# 196           7941942.0        1.857388e+07               False
# 207          15014834.0        1.820873e+07               False
#                            model_name  total_params  use_archer dataset_name  \
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 207  facebook/nllb-200-distilled-600M     615073792       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 208          3000                                     3000       en       fr
# 196          3000                                     3000       en       fr
# 207          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 208          32          4             128                    -1
# 196          32          4             128                    -1
# 207          32          2             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 208                do_not_pad  34.515130  39.005513  59.290880  57.095659
# 196         pad_to_max_length  34.515130  39.005513  59.290880  57.095659
# 207                do_not_pad  34.356154  38.659230  59.102346  56.915936
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 208  0.592607  35.789000           0.011184           0.005976
# 196  0.592607  35.789000           0.010550           0.005781
# 207  0.590741  35.575667           0.005580           0.005861
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 208           7491695.0        1.796747e+07               False
# 196           7941942.0        1.857388e+07               False
# 207          15014834.0        1.820873e+07               False
#                            model_name  total_params  use_archer dataset_name  \
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 207  facebook/nllb-200-distilled-600M     615073792       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 208          3000                                     3000       en       fr
# 196          3000                                     3000       en       fr
# 207          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 208          32          4             128                    -1
# 196          32          4             128                    -1
# 207          32          2             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 208                do_not_pad  34.515130  39.005513  59.290880  57.095659
# 196         pad_to_max_length  34.515130  39.005513  59.290880  57.095659
# 207                do_not_pad  34.356154  38.659230  59.102346  56.915936
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 208  0.592607  35.789000           0.011184           0.005976
# 196  0.592607  35.789000           0.010550           0.005781
# 207  0.590741  35.575667           0.005580           0.005861
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 208           7491695.0        1.796747e+07               False
# 196           7941942.0        1.857388e+07               False
# 207          15014834.0        1.820873e+07               False
#                            model_name  total_params  use_archer dataset_name  \
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 207  facebook/nllb-200-distilled-600M     615073792       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 208          3000                                     3000       en       fr
# 196          3000                                     3000       en       fr
# 207          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 208          32          4             128                    -1
# 196          32          4             128                    -1
# 207          32          2             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 208                do_not_pad  34.515130  39.005513  59.290880  57.095659
# 196         pad_to_max_length  34.515130  39.005513  59.290880  57.095659
# 207                do_not_pad  34.356154  38.659230  59.102346  56.915936
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 208  0.592607  35.789000           0.011184           0.005976
# 196  0.592607  35.789000           0.010550           0.005781
# 207  0.590741  35.575667           0.005580           0.005861
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 208           7491695.0        1.796747e+07               False
# 196           7941942.0        1.857388e+07               False
# 207          15014834.0        1.820873e+07               False
#                            model_name  total_params  use_archer dataset_name  \
# 206  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 194  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 203  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 191  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 90                           t5-large     737668096       False        wmt14
# 87                           t5-large     737668096       False        wmt14
# 127                           t5-base     222903552       False        wmt14
# 124                           t5-base     222903552       False        wmt14
# 402        google/switch_16_finetuned           630        True        wmt14
# 346        google/switch_16_finetuned           630        True        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 206          3000                                     3000       en       fr
# 194          3000                                     3000       en       fr
# 203          3000                                     3000       en       fr
# 191          3000                                     3000       en       fr
# 90           3000                                     3000       en       fr
# 87           3000                                     3000       en       fr
# 127          3000                                     3000       en       fr
# 124          3000                                     3000       en       fr
# 402          3000                                     3000       en       fr
# 346          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 206          32          1             128                    -1
# 194          32          1             128                    -1
# 203          32          1              64                    -1
# 191          32          1              64                    -1
# 90           32          1             128                    -1
# 87           32          1             128                    -1
# 127          32          1             128                    -1
# 124          32          1             128                    -1
# 402          32          1              32                    -1
# 346          32          1              32                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 206                do_not_pad  33.636513  37.724404  58.479601  56.319604
# 194         pad_to_max_length  33.636513  37.724404  58.479601  56.319604
# 203                do_not_pad  32.398901  36.274831  56.829105  54.724418
# 191         pad_to_max_length  32.398901  36.274831  56.829105  54.724418
# 90                 do_not_pad  32.085684  36.828827  58.115874  55.788274
# 87          pad_to_max_length  32.085684  36.828827  58.115874  55.788274
# 127                do_not_pad  31.235333  35.937655  57.400627  55.032425
# 124         pad_to_max_length  31.235333  35.937655  57.400627  55.032425
# 402               no_pad_fill   6.121815   7.247041  27.393845  25.376740
# 346               no_pad_fill   6.121815   7.247041  27.393845  25.376740
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 206  0.585461  35.034000           0.005564           0.005899
# 194  0.585461  35.034000           0.006055           0.005961
# 203  0.576788  33.765000           0.005660           0.005848
# 191  0.576788  33.765000           0.005766           0.005786
# 90   0.574383  39.319000           0.011003           0.015031
# 87   0.574383  39.319000           0.010922           0.015032
# 127  0.564298  39.499667           0.006290           0.007605
# 124  0.564298  39.499667           0.006166           0.007485
# 402  0.261448  26.332000           0.101974           0.063782
# 346  0.261448  26.332000           0.101428           0.062760
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 206         15059168.00        1.781566e+07               False
# 194         13837881.00        1.763131e+07               False
# 203         14803990.00        1.732245e+07               False
# 191         14530785.00        1.750658e+07               False
# 90           8644206.00        7.847833e+06               False
# 87           8708322.00        7.847112e+06               False
# 127         15119876.00        1.558253e+07               False
# 124         15424278.00        1.583257e+07               False
# 402           932672.56        1.238524e+06                 0.3
# 346           937687.10        1.258701e+06                 0.9
#                            model_name  total_params  use_archer dataset_name  \
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 207  facebook/nllb-200-distilled-600M     615073792       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 208          3000                                     3000       en       fr
# 196          3000                                     3000       en       fr
# 207          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 208          32          4             128                    -1
# 196          32          4             128                    -1
# 207          32          2             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 208                do_not_pad  34.515130  39.005513  59.290880  57.095659
# 196         pad_to_max_length  34.515130  39.005513  59.290880  57.095659
# 207                do_not_pad  34.356154  38.659230  59.102346  56.915936
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 208  0.592607  35.789000           0.011184           0.005976
# 196  0.592607  35.789000           0.010550           0.005781
# 207  0.590741  35.575667           0.005580           0.005861
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 208           7491695.0        1.796747e+07               False
# 196           7941942.0        1.857388e+07               False
# 207          15014834.0        1.820873e+07               False
#                            model_name  total_params  use_archer dataset_name  \
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 207  facebook/nllb-200-distilled-600M     615073792       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 208          3000                                     3000       en       fr
# 196          3000                                     3000       en       fr
# 207          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 208          32          4             128                    -1
# 196          32          4             128                    -1
# 207          32          2             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 208                do_not_pad  34.515130  39.005513  59.290880  57.095659
# 196         pad_to_max_length  34.515130  39.005513  59.290880  57.095659
# 207                do_not_pad  34.356154  38.659230  59.102346  56.915936
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 208  0.592607  35.789000           0.011184           0.005976
# 196  0.592607  35.789000           0.010550           0.005781
# 207  0.590741  35.575667           0.005580           0.005861
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 208           7491695.0        1.796747e+07               False
# 196           7941942.0        1.857388e+07               False
# 207          15014834.0        1.820873e+07               False
#                            model_name  total_params  use_archer dataset_name  \
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 207  facebook/nllb-200-distilled-600M     615073792       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 208          3000                                     3000       en       fr
# 196          3000                                     3000       en       fr
# 207          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 208          32          4             128                    -1
# 196          32          4             128                    -1
# 207          32          2             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 208                do_not_pad  34.515130  39.005513  59.290880  57.095659
# 196         pad_to_max_length  34.515130  39.005513  59.290880  57.095659
# 207                do_not_pad  34.356154  38.659230  59.102346  56.915936
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 208  0.592607  35.789000           0.011184           0.005976
# 196  0.592607  35.789000           0.010550           0.005781
# 207  0.590741  35.575667           0.005580           0.005861
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 208           7491695.0        1.796747e+07               False
# 196           7941942.0        1.857388e+07               False
# 207          15014834.0        1.820873e+07               False
#                            model_name  total_params  use_archer dataset_name  \
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 207  facebook/nllb-200-distilled-600M     615073792       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 208          3000                                     3000       en       fr
# 196          3000                                     3000       en       fr
# 207          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 208          32          4             128                    -1
# 196          32          4             128                    -1
# 207          32          2             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 208                do_not_pad  34.515130  39.005513  59.290880  57.095659
# 196         pad_to_max_length  34.515130  39.005513  59.290880  57.095659
# 207                do_not_pad  34.356154  38.659230  59.102346  56.915936
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 208  0.592607  35.789000           0.011184           0.005976
# 196  0.592607  35.789000           0.010550           0.005781
# 207  0.590741  35.575667           0.005580           0.005861
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 208           7491695.0        1.796747e+07               False
# 196           7941942.0        1.857388e+07               False
# 207          15014834.0        1.820873e+07               False
#                            model_name  total_params  use_archer dataset_name  \
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 207  facebook/nllb-200-distilled-600M     615073792       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 208          3000                                     3000       en       fr
# 196          3000                                     3000       en       fr
# 207          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 208          32          4             128                    -1
# 196          32          4             128                    -1
# 207          32          2             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 208                do_not_pad  34.515130  39.005513  59.290880  57.095659
# 196         pad_to_max_length  34.515130  39.005513  59.290880  57.095659
# 207                do_not_pad  34.356154  38.659230  59.102346  56.915936
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 208  0.592607  35.789000           0.011184           0.005976
# 196  0.592607  35.789000           0.010550           0.005781
# 207  0.590741  35.575667           0.005580           0.005861
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 208           7491695.0        1.796747e+07               False
# 196           7941942.0        1.857388e+07               False
# 207          15014834.0        1.820873e+07               False
#                            model_name  total_params  use_archer dataset_name  \
# 206  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 194  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 203  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 191  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 90                           t5-large     737668096       False        wmt14
# 87                           t5-large     737668096       False        wmt14
# 127                           t5-base     222903552       False        wmt14
# 124                           t5-base     222903552       False        wmt14
# 402        google/switch_16_finetuned           630        True        wmt14
# 346        google/switch_16_finetuned           630        True        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 206          3000                                     3000       en       fr
# 194          3000                                     3000       en       fr
# 203          3000                                     3000       en       fr
# 191          3000                                     3000       en       fr
# 90           3000                                     3000       en       fr
# 87           3000                                     3000       en       fr
# 127          3000                                     3000       en       fr
# 124          3000                                     3000       en       fr
# 402          3000                                     3000       en       fr
# 346          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 206          32          1             128                    -1
# 194          32          1             128                    -1
# 203          32          1              64                    -1
# 191          32          1              64                    -1
# 90           32          1             128                    -1
# 87           32          1             128                    -1
# 127          32          1             128                    -1
# 124          32          1             128                    -1
# 402          32          1              32                    -1
# 346          32          1              32                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 206                do_not_pad  33.636513  37.724404  58.479601  56.319604
# 194         pad_to_max_length  33.636513  37.724404  58.479601  56.319604
# 203                do_not_pad  32.398901  36.274831  56.829105  54.724418
# 191         pad_to_max_length  32.398901  36.274831  56.829105  54.724418
# 90                 do_not_pad  32.085684  36.828827  58.115874  55.788274
# 87          pad_to_max_length  32.085684  36.828827  58.115874  55.788274
# 127                do_not_pad  31.235333  35.937655  57.400627  55.032425
# 124         pad_to_max_length  31.235333  35.937655  57.400627  55.032425
# 402               no_pad_fill   6.121815   7.247041  27.393845  25.376740
# 346               no_pad_fill   6.121815   7.247041  27.393845  25.376740
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 206  0.585461  35.034000           0.005564           0.005899
# 194  0.585461  35.034000           0.006055           0.005961
# 203  0.576788  33.765000           0.005660           0.005848
# 191  0.576788  33.765000           0.005766           0.005786
# 90   0.574383  39.319000           0.011003           0.015031
# 87   0.574383  39.319000           0.010922           0.015032
# 127  0.564298  39.499667           0.006290           0.007605
# 124  0.564298  39.499667           0.006166           0.007485
# 402  0.261448  26.332000           0.101974           0.063782
# 346  0.261448  26.332000           0.101428           0.062760
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 206         15059168.00        1.781566e+07               False
# 194         13837881.00        1.763131e+07               False
# 203         14803990.00        1.732245e+07               False
# 191         14530785.00        1.750658e+07               False
# 90           8644206.00        7.847833e+06               False
# 87           8708322.00        7.847112e+06               False
# 127         15119876.00        1.558253e+07               False
# 124         15424278.00        1.583257e+07               False
# 402           932672.56        1.238524e+06                 0.3
# 346           937687.10        1.258701e+06                 0.9
#                            model_name  total_params  use_archer dataset_name  \
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 207  facebook/nllb-200-distilled-600M     615073792       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 208          3000                                     3000       en       fr
# 196          3000                                     3000       en       fr
# 207          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 208          32          4             128                    -1
# 196          32          4             128                    -1
# 207          32          2             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 208                do_not_pad  34.515130  39.005513  59.290880  57.095659
# 196         pad_to_max_length  34.515130  39.005513  59.290880  57.095659
# 207                do_not_pad  34.356154  38.659230  59.102346  56.915936
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 208  0.592607  35.789000           0.011184           0.005976
# 196  0.592607  35.789000           0.010550           0.005781
# 207  0.590741  35.575667           0.005580           0.005861
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 208           7491695.0        1.796747e+07               False
# 196           7941942.0        1.857388e+07               False
# 207          15014834.0        1.820873e+07               False
#                            model_name  total_params  use_archer dataset_name  \
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 207  facebook/nllb-200-distilled-600M     615073792       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 208          3000                                     3000       en       fr
# 196          3000                                     3000       en       fr
# 207          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 208          32          4             128                    -1
# 196          32          4             128                    -1
# 207          32          2             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 208                do_not_pad  34.515130  39.005513  59.290880  57.095659
# 196         pad_to_max_length  34.515130  39.005513  59.290880  57.095659
# 207                do_not_pad  34.356154  38.659230  59.102346  56.915936
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 208  0.592607  35.789000           0.011184           0.005976
# 196  0.592607  35.789000           0.010550           0.005781
# 207  0.590741  35.575667           0.005580           0.005861
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 208           7491695.0        1.796747e+07               False
# 196           7941942.0        1.857388e+07               False
# 207          15014834.0        1.820873e+07               False
#                            model_name  total_params  use_archer dataset_name  \
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 207  facebook/nllb-200-distilled-600M     615073792       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 208          3000                                     3000       en       fr
# 196          3000                                     3000       en       fr
# 207          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 208          32          4             128                    -1
# 196          32          4             128                    -1
# 207          32          2             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 208                do_not_pad  34.515130  39.005513  59.290880  57.095659
# 196         pad_to_max_length  34.515130  39.005513  59.290880  57.095659
# 207                do_not_pad  34.356154  38.659230  59.102346  56.915936
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 208  0.592607  35.789000           0.011184           0.005976
# 196  0.592607  35.789000           0.010550           0.005781
# 207  0.590741  35.575667           0.005580           0.005861
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 208           7491695.0        1.796747e+07               False
# 196           7941942.0        1.857388e+07               False
# 207          15014834.0        1.820873e+07               False
#                            model_name  total_params  use_archer dataset_name  \
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 207  facebook/nllb-200-distilled-600M     615073792       False        wmt14
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 208          3000                                     3000       en       fr
# 196          3000                                     3000       en       fr
# 207          3000                                     3000       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 208          32          4             128                    -1
# 196          32          4             128                    -1
# 207          32          2             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 208                do_not_pad  34.515130  39.005513  59.290880  57.095659
# 196         pad_to_max_length  34.515130  39.005513  59.290880  57.095659
# 207                do_not_pad  34.356154  38.659230  59.102346  56.915936
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 208  0.592607  35.789000           0.011184           0.005976
# 196  0.592607  35.789000           0.010550           0.005781
# 207  0.590741  35.575667           0.005580           0.005861
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 208           7491695.0        1.796747e+07               False
# 196           7941942.0        1.857388e+07               False
# 207          15014834.0        1.820873e+07               False
#                            model_name  total_params  use_archer dataset_name  \
# 208  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# 196  facebook/nllb-200-distilled-600M     615073792       False        wmt14
# ...
# 20            997                                      997       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 398          32          1             128                    -1
# 395          32          1              64                    -1
# 302          32          1             128                    -1
# 299          32          1             128                    -1
# 326          32          1             128                    -1
# 329          32          1             128                    -1
# 31           32          1             128                    -1
# 27           32          1              64                    -1
# 20           32          1              20                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 398         pad_to_max_length  45.001627  48.779117  67.568570  65.590515
# 395         pad_to_max_length  44.595661  48.324476  67.141963  65.162753
# 302                do_not_pad  44.502501  48.606894  67.344387  65.403968
# 299         pad_to_max_length  44.502501  48.606894  67.344387  65.403968
# 326         pad_to_max_length  43.837887  47.963790  66.892750  64.919023
# 329                do_not_pad  43.837887  47.963790  66.892750  64.919023
# 31                no_pad_fill  10.197941  11.867893  36.488121  33.928781
# 27                no_pad_fill   9.891538  11.517774  36.016647  33.474890
# 20                no_pad_fill   2.838825   3.128928  20.046494  18.418087
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 398  0.681717  38.966901           0.005550           0.006033
# 395  0.678395  38.588766           0.005493           0.005981
# 302  0.673387  44.852558           0.011388           0.014756
# 299  0.673387  44.852558           0.011301           0.014799
# 326  0.666688  44.922768           0.006043           0.007676
# 329  0.666688  44.922768           0.006519           0.007820
# 31   0.329115  44.572718           0.081635           0.042875
# 27   0.324723  41.837513           0.082612           0.052916
# 20   0.168386  18.921765           0.089382           0.057497
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 398          5567317.50        6.439312e+06               False
# 395          5625472.50        6.432318e+06               False
# 302          3004506.20        3.030491e+06               False
# 299          3027535.00        3.021724e+06               False
# 326          5662299.50        5.834850e+06               False
# 329          5248650.50        5.727557e+06               False
# 31            419124.20        1.036471e+06               False
# 27            414163.60        7.882636e+05               False
# 20            382797.22        3.281023e+05               False
#                            model_name  total_params  use_archer dataset_name  \
# 400  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 397  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 399  facebook/nllb-200-distilled-600M     615073792       False    flores200
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 400           997                                      997       en       fr
# 397           997                                      997       en       fr
# 399           997                                      997       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 400          32          4             128                    -1
# 397          32          4              64                    -1
# 399          32          2             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 400         pad_to_max_length  47.209741  51.276877  69.381455  67.416364
# 397         pad_to_max_length  46.694927  50.740721  68.883954  66.908898
# 399         pad_to_max_length  46.588451  50.587039  68.895572  66.947755
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 400  0.700522  40.112337           0.009295           0.005962
# 397  0.696565  39.671013           0.007200           0.005909
# 399  0.696386  39.769308           0.005532           0.005898
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 400           3324242.8        6.707889e+06               False
# 397           4291539.5        6.693638e+06               False
# 399           5585562.5        6.722573e+06               False
#                            model_name  total_params  use_archer dataset_name  \
# 400  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 397  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 399  facebook/nllb-200-distilled-600M     615073792       False    flores200
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 400           997                                      997       en       fr
# 397           997                                      997       en       fr
# 399           997                                      997       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 400          32          4             128                    -1
# 397          32          4              64                    -1
# 399          32          2             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 400         pad_to_max_length  47.209741  51.276877  69.381455  67.416364
# 397         pad_to_max_length  46.694927  50.740721  68.883954  66.908898
# 399         pad_to_max_length  46.588451  50.587039  68.895572  66.947755
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 400  0.700522  40.112337           0.009295           0.005962
# 397  0.696565  39.671013           0.007200           0.005909
# 399  0.696386  39.769308           0.005532           0.005898
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 400           3324242.8        6.707889e+06               False
# 397           4291539.5        6.693638e+06               False
# 399           5585562.5        6.722573e+06               False
#                            model_name  total_params  use_archer dataset_name  \
# 400  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 397  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 301                          t5-large     737668096       False    flores200
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 400           997                                      997       en       fr
# 397           997                                      997       en       fr
# 301           997                                      997       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 400          32          4             128                    -1
# 397          32          4              64                    -1
# 301          32          4             128                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 400         pad_to_max_length  47.209741  51.276877  69.381455  67.416364
# 397         pad_to_max_length  46.694927  50.740721  68.883954  66.908898
# 301         pad_to_max_length  46.134082  50.667496  68.694641  66.723533
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 400  0.700522  40.112337           0.009295           0.005962
# 397  0.696565  39.671013           0.007200           0.005909
# 301  0.684410  45.785356           0.011248           0.023786
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 400           3324242.8        6.707889e+06               False
# 397           4291539.5        6.693638e+06               False
# 301           3041943.2        1.919150e+06               False
#                            model_name  total_params  use_archer dataset_name  \
# 400  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 399  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 397  facebook/nllb-200-distilled-600M     615073792       False    flores200
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 400           997                                      997       en       fr
# 399           997                                      997       en       fr
# 397           997                                      997       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 400          32          4             128                    -1
# 399          32          2             128                    -1
# 397          32          4              64                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 400         pad_to_max_length  47.209741  51.276877  69.381455  67.416364
# 399         pad_to_max_length  46.588451  50.587039  68.895572  66.947755
# 397         pad_to_max_length  46.694927  50.740721  68.883954  66.908898
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 400  0.700522  40.112337           0.009295           0.005962
# 399  0.696386  39.769308           0.005532           0.005898
# 397  0.696565  39.671013           0.007200           0.005909
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 400           3324242.8        6.707889e+06               False
# 399           5585562.5        6.722573e+06               False
# 397           4291539.5        6.693638e+06               False
#                            model_name  total_params  use_archer dataset_name  \
# 400  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 399  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 397  facebook/nllb-200-distilled-600M     615073792       False    flores200
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 400           997                                      997       en       fr
# 399           997                                      997       en       fr
# 397           997                                      997       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 400          32          4             128                    -1
# 399          32          2             128                    -1
# 397          32          4              64                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 400         pad_to_max_length  47.209741  51.276877  69.381455  67.416364
# 399         pad_to_max_length  46.588451  50.587039  68.895572  66.947755
# 397         pad_to_max_length  46.694927  50.740721  68.883954  66.908898
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 400  0.700522  40.112337           0.009295           0.005962
# 399  0.696386  39.769308           0.005532           0.005898
# 397  0.696565  39.671013           0.007200           0.005909
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 400           3324242.8        6.707889e+06               False
# 399           5585562.5        6.722573e+06               False
# 397           4291539.5        6.693638e+06               False
#                            model_name  total_params  use_archer dataset_name  \
# 398  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 395  facebook/nllb-200-distilled-600M     615073792       False    flores200
# 302                          t5-large     737668096       False    flores200
# 299                          t5-large     737668096       False    flores200
# 326                           t5-base     222903552       False    flores200
# 329                           t5-base     222903552       False    flores200
# 31         google/switch_16_finetuned           630        True    flores200
# 27         google/switch_16_finetuned           630        True    flores200
# 20         google/switch_16_finetuned           630        True    flores200
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 398           997                                      997       en       fr
# 395           997                                      997       en       fr
# 302           997                                      997       en       fr
# 299           997                                      997       en       fr
# 326           997                                      997       en       fr
# 329           997                                      997       en       fr
# 31            997                                      997       en       fr
# 27            997                                      997       en       fr
# 20            997                                      997       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 398          32          1             128                    -1
# 395          32          1              64                    -1
# 302          32          1             128                    -1
# 299          32          1             128                    -1
# 326          32          1             128                    -1
# 329          32          1             128                    -1
# 31           32          1             128                    -1
# 27           32          1              64                    -1
# 20           32          1              20                    -1
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 398         pad_to_max_length  45.001627  48.779117  67.568570  65.590515
# 395         pad_to_max_length  44.595661  48.324476  67.141963  65.162753
# 302                do_not_pad  44.502501  48.606894  67.344387  65.403968
# 299         pad_to_max_length  44.502501  48.606894  67.344387  65.403968
# 326         pad_to_max_length  43.837887  47.963790  66.892750  64.919023
# 329                do_not_pad  43.837887  47.963790  66.892750  64.919023
# 31                no_pad_fill  10.197941  11.867893  36.488121  33.928781
# 27                no_pad_fill   9.891538  11.517774  36.016647  33.474890
# 20                no_pad_fill   2.838825   3.128928  20.046494  18.418087
#
#        meteor    gen_len  encoder_latency_s  decoder_latency_s  \
# 398  0.681717  38.966901           0.005550           0.006033
# 395  0.678395  38.588766           0.005493           0.005981
# 302  0.673387  44.852558           0.011388           0.014756
# 299  0.673387  44.852558           0.011301           0.014799
# 326  0.666688  44.922768           0.006043           0.007676
# 329  0.666688  44.922768           0.006519           0.007820
# 31   0.329115  44.572718           0.081635           0.042875
# 27   0.324723  41.837513           0.082612           0.052916
# 20   0.168386  18.921765           0.089382           0.057497
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 398          5567317.50        6.439312e+06               False
# 395          5625472.50        6.432318e+06               False
# 302          3004506.20        3.030491e+06               False
# 299          3027535.00        3.021724e+06               False
# 326          5662299.50        5.834850e+06               False
# 329          5248650.50        5.727557e+06               False
# 31            419124.20        1.036471e+06               False
# 27            414163.60        7.882636e+05               False
# 20            382797.22        3.281023e+05               False

# %% [markdown]
# 	model_name	total_params	use_archer	dataset_name	dataset_size	dataset_size_after_filter_wrt_input_len	src_lang	tgt_lang	batch_size	beam_size	max_gen_length	max_input_seq_length	tokenizer_padding_setting	sacrebleu	spBleu	chrf	chrfpp	meteor	gen_len	encoder_latency_s	decoder_latency_s	encoder_throughput	decoder_throughput	device_memory_ratio
# 89	t5-large	737668096	False	wmt14	3000	3000	en	fr	32	4	128	-1	pad_to_max_length	32.789237	37.810019	58.650936	56.311633	0.58	39.982	0.012072	0.023508	7878415.5	5.102418e+06	False

# %%
#Show best performing stats for every model:


metrics = ["sacrebleu", "spBleu", "chrf", "chrfpp", "meteor"]
dataset_names = ["wmt14", "flores200"]
model_names = df_merge_all_temp["model_name"].drop_duplicates().values

best_models_wmt14 = {}
best_models_flores = {}
for ds_name in dataset_names:
    print("-------")
    print(ds_name)
    
    for metric in metrics:
    
        df_merge_all_temp_ds = df_merge_all_temp[df_merge_all_temp["dataset_name"] == ds_name]

        save_best = {}

        if ds_name == "wmt14":
            save_best = best_models_wmt14
        else:
            save_best = best_models_flores


        if save_best.get(metric) is None:
            save_best[metric] = []
        for model_name in model_names:
            
            
            df_merge_all_temp_ds = df_merge_all_temp_ds.sort_values(metric, ascending=False)
            x= df_merge_all_temp_ds[df_merge_all_temp_ds["model_name"] == model_name]
            m = save_best[metric]
            m.append(x.iloc[0])
            save_best[metric] = m

        if ds_name == "wmt14":
            best_models_wmt14 = save_best
        else:
            best_models_flores = save_best



# print(best_models_wmt14)


# print(best_models_flores)
# Out:
# -------
# wmt14
# -------
# flores200
#                                            sacrebleu  \
# 0  model_name                                 fac...
# 1  model_name                                    ...
# 2  model_name                                    ...
# 3  model_name                                 goo...
# 4  model_name                                 goo...
#
#                                               spBleu  \
# 0  model_name                                 fac...
# 1  model_name                                    ...
# 2  model_name                                    ...
# 3  model_name                                 goo...
# 4  model_name                                 goo...
#
#                                                 chrf  \
# 0  model_name                                 fac...
# 1  model_name                                    ...
# 2  model_name                                    ...
# 3  model_name                                 goo...
# 4  model_name                                 goo...
#
#                                               chrfpp  \
# 0  model_name                                 fac...
# 1  model_name                                    ...
# 2  model_name                                    ...
# 3  model_name                                 goo...
# 4  model_name                                 goo...
#
#                                               meteor
# 0  model_name                                 fac...
# 1  model_name                                    ...
# 2  model_name                                    ...
# 3  model_name                                 goo...
# 4  model_name                                 goo...

# %%
metrics = ["sacrebleu", "spBleu", "chrf", "chrfpp", "meteor"]
dataset_names = ["wmt14", "flores200"]
model_names = df_merge_all_temp["model_name"].drop_duplicates().values

for ds_name in dataset_names:
    print("-------")
    print(ds_name)
    
    
    df_merge_all_temp_ds = df_merge_all_temp[df_merge_all_temp["dataset_name"] == ds_name]
    for metric in metrics:
        out = df_merge_all_temp_ds.groupby(['model_name'])[metric].nlargest(1).droplevel(1).loc[df_merge_all_temp_ds['model_name'].drop_duplicates()].reset_index()
        
        display(out)
# Out:
# -------
# wmt14
#                          model_name  sacrebleu
# 0  facebook/nllb-200-distilled-600M  34.515130
# 1                          t5-large  32.789237
# 2                           t5-base  31.960216
# 3        google/switch_16_finetuned   6.121815
# 4            google/switch-base-128   0.000000
#                          model_name     spBleu
# 0  facebook/nllb-200-distilled-600M  39.005513
# 1                          t5-large  37.810019
# 2                           t5-base  36.953311
# 3        google/switch_16_finetuned   7.247041
# 4            google/switch-base-128   0.006250
#                          model_name       chrf
# 0  facebook/nllb-200-distilled-600M  59.290880
# 1                          t5-large  58.650936
# 2                           t5-base  58.056526
# 3        google/switch_16_finetuned  27.393845
# 4            google/switch-base-128   1.534227
#                          model_name     chrfpp
# 0  facebook/nllb-200-distilled-600M  57.095659
# 1                          t5-large  56.311633
# 2                           t5-base  55.693858
# 3        google/switch_16_finetuned  25.376740
# 4            google/switch-base-128   1.973425
#                          model_name    meteor
# 0  facebook/nllb-200-distilled-600M  0.592607
# 1                          t5-large  0.580000
# 2                           t5-base  0.572865
# 3        google/switch_16_finetuned  0.261448
# 4            google/switch-base-128  0.027693
# -------
# flores200
#                          model_name  sacrebleu
# 0  facebook/nllb-200-distilled-600M  47.209741
# 1                          t5-large  46.134082
# 2                           t5-base  44.969011
# 3        google/switch_16_finetuned  11.811318
# 4            google/switch-base-128   0.000000
#                          model_name     spBleu
# 0  facebook/nllb-200-distilled-600M  51.276877
# 1                          t5-large  50.667496
# 2                           t5-base  49.504846
# 3        google/switch_16_finetuned  14.193317
# 4            google/switch-base-128   0.012786
#                          model_name       chrf
# 0  facebook/nllb-200-distilled-600M  69.381455
# 1                          t5-large  68.694641
# 2                           t5-base  67.912596
# 3        google/switch_16_finetuned  39.302815
# 4            google/switch-base-128   1.602607
#                          model_name     chrfpp
# 0  facebook/nllb-200-distilled-600M  67.416364
# 1                          t5-large  66.723533
# 2                           t5-base  65.924518
# 3        google/switch_16_finetuned  36.517678
# 4            google/switch-base-128   1.972509
#                          model_name    meteor
# 0  facebook/nllb-200-distilled-600M  0.700522
# 1                          t5-large  0.684410
# 2                           t5-base  0.677273
# 3        google/switch_16_finetuned  0.350495
# 4            google/switch-base-128  0.022311

# %%
from pylatex import Document, Package, Section, NoEscape
pd.set_option('display.float_format','{:.3f}'.format)
pd.set_option('display.float_format', '{:.3g}'.format)

# %%
dataset_names = ["wmt14", "flores200"]
metrics = ["sacrebleu", "spBleu", "chrf", "chrfpp", "meteor"]
speed = ["encoder_latency_s", "decoder_latency_s", "encoder_throughput", "decoder_throughput"]

model_names = df_merge_all_temp["model_name"].drop_duplicates().values
for ds_name in dataset_names:
    print("----")
    print(ds_name)
    df_merge_all_temp_ds = df_merge_all_temp[df_merge_all_temp["dataset_name"] == ds_name]
    df_merge_all_temp_ds = df_merge_all_temp_ds.sort_values(metric, ascending=False)

    df_merge_all_temp_ds = df_merge_all_temp_ds.drop_duplicates(subset=['model_name'], keep='first')

    
    display(df_merge_all_temp_ds[["model_name"] + metrics])

    display(df_merge_all_temp_ds[["model_name"] + speed])

    
    
    # print(NoEscape(df_merge_all_temp_ds[["model_name"] + speed].to_latex(float_format="{:.3f}".format)))
# Out:
# ----
# wmt14
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 10
#       8 print(ds_name)
#       9 df_merge_all_temp_ds = df_merge_all_temp[df_merge_all_temp["dataset_name"] == ds_name]
# ---> 10 df_merge_all_temp_ds = df_merge_all_temp_ds.sort_values(metric, ascending=False)
#      12 df_merge_all_temp_ds = df_merge_all_temp_ds.drop_duplicates(subset=['model_name'], keep='first')
#      15 display(df_merge_all_temp_ds[["model_name"] + metrics])
#
# NameError: name 'metric' is not defined

# %% [markdown]
# # Check score of meteor for single sentences

# %%
df_merge_all_temp = copy.deepcopy(df_merge_all)
df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("facebook/", "")
df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("google/", "")
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["model_name"] != "switch-base-128"]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["beam_size"] != 8]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["dataset_size"] == 1]
# df_merge_all_temp.sort_values("encoder_latency_s",ascending=False).head(3)
# Out:
#       model_name  total_params  use_archer dataset_name  dataset_size  \
# 40  nllb-moe-54b     524717009       False    flores200             1
# 41  nllb-moe-54b     524717009       False    flores200             1
# 54  nllb-moe-54b     524717009       False        wmt14             1
#
#     dataset_size_after_filter_wrt_input_len src_lang tgt_lang  batch_size  \
# 40                                        1       en       fr           1
# 41                                        1       en       fr           1
# 54                                        1       en       fr           1
#
#     beam_size  max_gen_length  max_input_seq_length tokenizer_padding_setting  \
# 40          1              20                    -1               no_pad_fill
# 41          2              20                    -1               no_pad_fill
# 54          1              20                    -1               no_pad_fill
#
#     sacrebleu  spBleu  chrf  chrfpp  meteor  gen_len  encoder_latency_s  \
# 40          0       0  4.24    3.18       0       20                122
# 41          0       0  3.49    2.61       0       20                122
# 54          0       0  12.2    9.17       0       20               63.2
#
#     decoder_latency_s  encoder_throughput  decoder_throughput  \
# 40               2.48               0.523                8.07
# 41                3.3               0.526                6.05
# 54               2.49               0.332                8.04
#
#    device_memory_ratio
# 40               False
# 41               False
# 54               False

# %% [markdown]
# # Check best latency and throughput for single sentences for the best parameters

# %%
import numpy as np
df_merge_all_temp = copy.deepcopy(df_merge_all)
df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("facebook/", "")
df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("google/", "")
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["model_name"] != "switch-base-128"]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["model_name"] != "switch_16_finetuned"]

df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["beam_size"] != 8]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["dataset_size"] == 1]
df_merge_all_temp.sort_values("encoder_latency_s",ascending=False).head(3)
df_merge_all_temp = df_merge_all_temp[(df_merge_all_temp["batch_size"] == 32) & (df_merge_all_temp["beam_size"] == 4) & (df_merge_all_temp["max_gen_length"] == 128) & (df_merge_all_temp["max_input_seq_length"] == 15)]


batch_size = 32
beam_size = 4
max_generation_length = 128
max_input_seq_len = 15

df_merge_all_temp
# Out:
#     model_name  total_params  use_archer dataset_name  dataset_size  \
# 77    t5-large     737668096       False        wmt14             1
# 80    t5-large     737668096       False        wmt14             1
# 114    t5-base     222903552       False        wmt14             1
# 117    t5-base     222903552       False        wmt14             1
#
#      dataset_size_after_filter_wrt_input_len src_lang tgt_lang  batch_size  \
# 77                                         1       en       fr          32
# 80                                         1       en       fr          32
# 114                                        1       en       fr          32
# 117                                        1       en       fr          32
#
#      beam_size  max_gen_length  max_input_seq_length  \
# 77           4             128                    15
# 80           4             128                    15
# 114          4             128                    15
# 117          4             128                    15
#
#     tokenizer_padding_setting  sacrebleu  spBleu  chrf  chrfpp  meteor  \
# 77          pad_to_max_length        100     100   100     100   0.999
# 80                 do_not_pad        100     100   100     100   0.999
# 114         pad_to_max_length        100     100   100     100   0.999
# 117                do_not_pad        100     100   100     100   0.999
#
#      gen_len  encoder_latency_s  decoder_latency_s  encoder_throughput  \
# 77        19             0.0134             0.0145            1.41e+03
# 80        19             0.0135             0.0147            1.41e+03
# 114       19            0.00968            0.00735            1.96e+03
# 117       19            0.00807            0.00746            2.36e+03
#
#      decoder_throughput device_memory_ratio
# 77             1.31e+03               False
# 80              1.3e+03               False
# 114            2.59e+03               False
# 117            2.55e+03               False

# %%
Check if i analysed this max_input_seq_len

# %% [markdown]
# ## Extra

# %% [markdown]
# ## Investigating Beam Size

# %%
# Effect of beam size on latency and throughput
# fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))
import copy

df_merge_all_temp = copy.deepcopy(df_merge_all)
df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("facebook/", "")
df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("google/", "")
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["model_name"] != "switch-base-128"]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["beam_size"] != 8]

g= sns.barplot(data=df_merge_all_temp, x="beam_size", y="decoder_latency_s", hue="model_name");
# plt.xticks(df_merge_all_temp["beam_size"])
# plt.xticks(df_merge_all_temp["beam_size"])
# plt.xlim([0, 32])

# g.ax_joint.set_yscale('log')
# g.ax_joint.set_xscale('log')
plt.show()

# g.ax_joint.set_title("Beam size vs Encoder Latency")
# df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["model_name"] != "nllb-moe-54b"]

# g= sns.jointplot(data=df_merge_all_temp, x="beam_size", y="decoder_throughput", hue="model_name",);
# plt.show()
g= sns.barplot(data=df_merge_all_temp, x="beam_size", y="decoder_throughput", hue="model_name");
# g= sns.despine()

# plt.xticks(df_merge_all["beam_size"])
# plt.xticks(df_merge_all["beam_size"])
# g.ax_joint.set_yscale('log')
# g.ax_joint.set_xscale('log')

plt.savefig("beam_size",
    dpi=300,
    bbox_inches="tight")

plt.show()

# plt.savefig(
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       1 # Effect of beam size on latency and throughput
#       2 # fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))
#       3 import copy
# ----> 5 df_merge_all_temp = copy.deepcopy(df_merge_all)
#       6 df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("facebook/", "")
#       7 df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("google/", "")
#
# NameError: name 'df_merge_all' is not defined

# %%
# Effect of beam size on latency and throughput
# fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))
import copy

df_merge_all_temp = copy.deepcopy(df_merge_all)
df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("facebook/", "")
df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("google/", "")
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["model_name"] != "switch-base-128"]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["model_name"] != "switch_16_finetuned"]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["model_name"] != "nllb-moe-54b"]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["beam_size"] != 8]

g= sns.barplot(data=df_merge_all_temp, x="beam_size", y="sacrebleu", hue="model_name");
# plt.xticks(df_merge_all_temp["beam_size"])
# plt.xticks(df_merge_all_temp["beam_size"])
# plt.xlim([0, 32])

# g.ax_joint.set_yscale('log')
# g.ax_joint.set_xscale('log')

plt.title("Decoder Latency on Different Beam Sizes")

plt.savefig("beam_size_vs_decoder_latency_s.png",
    dpi=300,
    bbox_inches="tight")

plt.show()

# g.ax_joint.set_title("Beam size vs Encoder Latency")
# df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["model_name"] != "nllb-moe-54b"]

# g= sns.jointplot(data=df_merge_all_temp, x="beam_size", y="decoder_throughput", hue="model_name",);
# plt.show()
g= sns.barplot(data=df_merge_all_temp, x="beam_size", y="decoder_throughput", hue="model_name");
# g= sns.despine()

# plt.xticks(df_merge_all["beam_size"])
# plt.xticks(df_merge_all["beam_size"])
# g.ax_joint.set_yscale('log')
# g.ax_joint.set_xscale('log')

plt.title("Decoder Throughput on Different Beam Sizes")

plt.savefig("beam_size_vs_decoder_throughput.png",
    dpi=300,
    bbox_inches="tight")
plt.show()

# plt.savefig(

# %%
g = sns.catplot(x="Cholesterol", y="HeartDisease", row="ChestPainType",
                kind="box", orient="h", height=1.5, aspect=4,
                data=heart.query("Cholesterol > 0"))
g.set(xscale="log");

# %%
# Effect of beam size on accuracy
# Effect of beam size on latency and throughput
# fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))
import copy
df_merge_all_temp = copy.deepcopy(df_merge_wmt14_multiple_sentences)
df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("facebook/", "")
df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("google/", "")
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["model_name"].isin(["t5-large","t5-base", "nllb-200-distilled-600M"])]

g= sns.jointplot(data=df_merge_all_temp, x="beam_size", y="sacrebleu", hue="model_name", ax=axes[0,0]);
plt.xticks(df_merge_all["beam_size"])
plt.xticks(df_merge_all["beam_size"])
plt.xlim([0, 16])

# g.ax_joint.set_yscale('log')
# g.ax_joint.set_xscale('log')

# %%
df_merge_all_temp
# Out:
#                   model_name  total_params  use_archer dataset_name  \
# 69                  t5-large     737668096       False        wmt14
# 70                  t5-large     737668096       False        wmt14
# 71                  t5-large     737668096       False        wmt14
# 72                  t5-large     737668096       False        wmt14
# 73                  t5-large     737668096       False        wmt14
# ..                       ...           ...         ...          ...
# 396  nllb-200-distilled-600M     615073792       False    flores200
# 397  nllb-200-distilled-600M     615073792       False    flores200
# 398  nllb-200-distilled-600M     615073792       False    flores200
# 399  nllb-200-distilled-600M     615073792       False    flores200
# 400  nllb-200-distilled-600M     615073792       False    flores200
#
#      dataset_size  dataset_size_after_filter_wrt_input_len src_lang tgt_lang  \
# 69              1                                        1       en       fr
# 70              1                                        1       en       fr
# 71              1                                        1       en       fr
# 72              1                                        1       en       fr
# 73              1                                        1       en       fr
# ..            ...                                      ...      ...      ...
# 396           997                                      997       en       fr
# 397           997                                      997       en       fr
# 398           997                                      997       en       fr
# 399           997                                      997       en       fr
# 400           997                                      997       en       fr
#
#      batch_size  beam_size  max_gen_length  max_input_seq_length  \
# 69           32          1             128                    -1
# 70           32          2             128                    -1
# 71           32          4             128                    -1
# 72           32          1             128                    -1
# 73           32          2             128                    -1
# ..          ...        ...             ...                   ...
# 396          32          2              64                    -1
# 397          32          4              64                    -1
# 398          32          1             128                    -1
# 399          32          2             128                    -1
# 400          32          4             128                    -1
#
#     tokenizer_padding_setting  sacrebleu  spBleu  chrf  chrfpp  meteor  \
# 69          pad_to_max_length        100     100   100     100   0.999
# 70          pad_to_max_length        100     100   100     100   0.999
# 71          pad_to_max_length        100     100   100     100   0.999
# 72                 do_not_pad        100     100   100     100   0.999
# 73                 do_not_pad        100     100   100     100   0.999
# ..                        ...        ...     ...   ...     ...     ...
# 396         pad_to_max_length       46.1    50.1  68.4    66.5   0.693
# 397         pad_to_max_length       46.7    50.7  68.9    66.9   0.697
# 398         pad_to_max_length         45    48.8  67.6    65.6   0.682
# 399         pad_to_max_length       46.6    50.6  68.9    66.9   0.696
# 400         pad_to_max_length       47.2    51.3  69.4    67.4   0.701
#
#      gen_len  encoder_latency_s  decoder_latency_s  encoder_throughput  \
# 69        19             0.0131             0.0133            1.46e+03
# 70        19             0.0101             0.0145            1.89e+03
# 71        19              0.013             0.0146            1.46e+03
# 72        19             0.0146             0.0132             1.3e+03
# 73        19              0.014             0.0145            1.36e+03
# ..       ...                ...                ...                 ...
# 396     39.4            0.00553            0.00585            5.59e+06
# 397     39.7             0.0072            0.00591            4.29e+06
# 398       39            0.00555            0.00603            5.57e+06
# 399     39.8            0.00553             0.0059            5.59e+06
# 400     40.1             0.0093            0.00596            3.32e+06
#
#      decoder_throughput device_memory_ratio
# 69             1.43e+03               False
# 70             1.31e+03               False
# 71              1.3e+03               False
# 72             1.44e+03               False
# 73             1.31e+03               False
# ..                  ...                 ...
# 396            6.71e+06               False
# 397            6.69e+06               False
# 398            6.44e+06               False
# 399            6.72e+06               False
# 400            6.71e+06               False
#
# [228 rows x 24 columns]

# %% [markdown]
# # Input Sequence Length

# %%
# Effect of beam size on latency and throughput
# fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))
import copy

df_merge_all_temp = copy.deepcopy(df_merge_all)
df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("facebook/", "")
df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("google/", "")
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["model_name"] != "switch-base-128"]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["model_name"] != "switch_16_finetuned"]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["model_name"] != "nllb-moe-54b"]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["beam_size"] != 8]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["max_input_seq_length"] != 10]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["dataset_size"] != 1]

# df_merge_all_temp = df_merge_all_temp["max_input_seq_length"] 
display(df_merge_all_temp[df_merge_all_temp["model_name"] == "t5-large"].sort_values("decoder_latency_s").head(1))

g= sns.barplot(data=df_merge_all_temp, x="max_input_seq_length", y="decoder_latency_s", hue="model_name");
# plt.xticks(df_merge_all_temp["beam_size"])
# plt.xticks(df_merge_all_temp["beam_size"])
# plt.xlim([0, 32])

# g.ax_joint.set_yscale('log')
# g.ax_joint.set_xscale('log')

plt.title("Decoder Latency on Different Sequence Lengths")

plt.savefig("input_sequence_len_decode_latency.png",
    dpi=300,
    bbox_inches="tight")

plt.show()

plt.xticks(df_merge_all["max_input_seq_length"])

# g.ax_joint.set_title("Beam size vs Encoder Latency")
# df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["model_name"] != "nllb-moe-54b"]

# g= sns.jointplot(data=df_merge_all_temp, x="beam_size", y="decoder_throughput", hue="model_name",);
# plt.show()
g= sns.barplot(data=df_merge_all_temp, x="max_input_seq_length", y="decoder_throughput", hue="model_name");
# g= sns.despine()

# plt.xticks(df_merge_all["beam_size"])
# plt.xticks(df_merge_all["beam_size"])
# g.set_yscale('log')
# g.ax_joint.set_xscale('log')

plt.title("Decoder Throughput on Different Sequence Lengths")

plt.savefig("input_sequence_len_decode_troughput.png",
    dpi=300,
    bbox_inches="tight")
plt.show()




g= sns.barplot(data=df_merge_all_temp, x="max_input_seq_length", y="encoder_latency_s", hue="model_name");
# plt.xticks(df_merge_all_temp["beam_size"])
# plt.xticks(df_merge_all_temp["beam_size"])
# plt.xlim([0, 32])

# g.ax_joint.set_yscale('log')
# g.ax_joint.set_xscale('log')

plt.title("Encoder Latency on Different Sequence Lengths")

plt.savefig("input_sequence_len_encode_latency.png",
    dpi=300,
    bbox_inches="tight")

plt.show()

plt.xticks(df_merge_all["max_input_seq_length"])

# g.ax_joint.set_title("Beam size vs Encoder Latency")
# df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["model_name"] != "nllb-moe-54b"]

# g= sns.jointplot(data=df_merge_all_temp, x="beam_size", y="decoder_throughput", hue="model_name",);
# plt.show()
g= sns.barplot(data=df_merge_all_temp, x="max_input_seq_length", y="encoder_throughput", hue="model_name");
# g= sns.despine()

# plt.xticks(df_merge_all["beam_size"])
# plt.xticks(df_merge_all["beam_size"])
# g.set_yscale('log')
# g.ax_joint.set_xscale('log')

plt.title("Encoder Throughput on Different Sequence Lengths")

plt.savefig("input_sequence_len_encode_troughput.png",
    dpi=300,
    bbox_inches="tight")
plt.show()




# plt.savefig(
# Out:
#     model_name  total_params  use_archer dataset_name  dataset_size  \
# 314   t5-large     737668096       False    flores200           997
#
#      dataset_size_after_filter_wrt_input_len src_lang tgt_lang  batch_size  \
# 314                                      898       en       fr          32
#
#      beam_size  max_gen_length  max_input_seq_length  \
# 314          2             128                    30
#
#     tokenizer_padding_setting  sacrebleu     spBleu       chrf     chrfpp  \
# 314         pad_to_max_length    45.6475  50.055662  68.372035  66.396762
#
#        meteor   gen_len  encoder_latency_s  decoder_latency_s  \
# 314  0.682837  42.41314           0.011025           0.014539
#
#      encoder_throughput  decoder_throughput device_memory_ratio
# 314           2638212.5        2.619555e+06               False

# %% [markdown]
# ## MoE Inference

# %%
df_merge_all_temp = copy.deepcopy(df_merge_all)
df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("facebook/", "")
df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("google/", "")
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["model_name"] == "nllb-moe-54b"]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["beam_size"] != 8]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["dataset_name"] == "wmt14"]
print("wmt14")
# display(df_merge_all_temp.sort_values("encoder_latency_s").head(3))
# display(df_merge_all_temp.sort_values("decoder_latency_s").head(3))
# display(df_merge_all_temp.sort_values("encoder_throughput", ascending=False).head(3))
# display(df_merge_all_temp.sort_values("decoder_throughput", ascending=False).head(3))


cols = ["sacrebleu",	"spBleu"	, "chrf"	,"chrfpp"]
speed = ["encoder_latency_s", "decoder_latency_s", "encoder_throughput", "decoder_throughput"]

# display(df_merge_all_temp.sort_values("decoder_throughput", ascending=False).head(3)[cols])
# display(df_merge_all_temp.sort_values("decoder_throughput", ascending=False).head(3)[speed])



df_merge_all_temp = copy.deepcopy(df_merge_all)
df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("facebook/", "")
df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("google/", "")
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["model_name"] == "nllb-moe-54b"]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["beam_size"] != 8]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["dataset_name"] == "wmt14"]
print("wmt14")
# display(df_merge_all_temp.sort_values("encoder_latency_s").head(3))
# display(df_merge_all_temp.sort_values("decoder_latency_s").head(3))
# display(df_merge_all_temp.sort_values("decoder_latency_s", ascending=False).head(3))
# display(df_merge_all_temp.sort_values("decoder_throughput", ascending=False).head(3))


cols = ["sacrebleu",	"spBleu"	, "chrf"	,"chrfpp"]
speed = ["encoder_latency_s", "decoder_latency_s", "encoder_throughput", "decoder_throughput"]


cols.extend(["beam_size" , "max_gen_length"])
speed.extend(["beam_size" , "max_gen_length"])

# display(df_merge_all_temp.sort_values("encoder_latency_s", ascending=False).head(3)[cols])
display(df_merge_all_temp.sort_values("encoder_latency_s", ascending=True).head(3)[speed])
# Out:
# wmt14
# wmt14
#     encoder_latency_s  decoder_latency_s  encoder_throughput  \
# 63           1.172449           0.114301           17.911232
# 61           1.173007           0.393618           17.902699
# 65           1.221783           0.343588           17.187994
#
#     decoder_throughput  beam_size  max_gen_length
# 63         1119.852697          1             128
# 61          162.594157          2              64
# 65          372.539494          4             128

# %%
df_merge_all_temp = copy.deepcopy(df_merge_all)
df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("facebook/", "")
df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("google/", "")
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["model_name"] == "nllb-moe-54b"]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["beam_size"] != 8]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["dataset_name"] == "wmt14"]

print("BEST")
display(df_merge_all_temp.sort_values("encoder_latency_s").head(1))
display(df_merge_all_temp.sort_values("decoder_latency_s").head(1))
display(df_merge_all_temp.sort_values("encoder_throughput", ascending=False).head(1))
display(df_merge_all_temp.sort_values("decoder_throughput", ascending=False).head(1))
# Out:
# BEST
#       model_name  total_params  use_archer dataset_name  dataset_size  \
# 63  nllb-moe-54b     524717009       False        wmt14             1
#
#     dataset_size_after_filter_wrt_input_len src_lang tgt_lang  batch_size  \
# 63                                        1       en       fr           1
#
#     beam_size  max_gen_length  max_input_seq_length tokenizer_padding_setting  \
# 63          1             128                    -1               no_pad_fill
#
#     sacrebleu  spBleu  chrf  chrfpp  meteor  gen_len  encoder_latency_s  \
# 63          0       0  7.12    5.34       0      128               1.17
#
#     decoder_latency_s  encoder_throughput  decoder_throughput  \
# 63              0.114                17.9            1.12e+03
#
#    device_memory_ratio
# 63               False
#       model_name  total_params  use_archer dataset_name  dataset_size  \
# 63  nllb-moe-54b     524717009       False        wmt14             1
#
#     dataset_size_after_filter_wrt_input_len src_lang tgt_lang  batch_size  \
# 63                                        1       en       fr           1
#
#     beam_size  max_gen_length  max_input_seq_length tokenizer_padding_setting  \
# 63          1             128                    -1               no_pad_fill
#
#     sacrebleu  spBleu  chrf  chrfpp  meteor  gen_len  encoder_latency_s  \
# 63          0       0  7.12    5.34       0      128               1.17
#
#     decoder_latency_s  encoder_throughput  decoder_throughput  \
# 63              0.114                17.9            1.12e+03
#
#    device_memory_ratio
# 63               False
#       model_name  total_params  use_archer dataset_name  dataset_size  \
# 63  nllb-moe-54b     524717009       False        wmt14             1
#
#     dataset_size_after_filter_wrt_input_len src_lang tgt_lang  batch_size  \
# 63                                        1       en       fr           1
#
#     beam_size  max_gen_length  max_input_seq_length tokenizer_padding_setting  \
# 63          1             128                    -1               no_pad_fill
#
#     sacrebleu  spBleu  chrf  chrfpp  meteor  gen_len  encoder_latency_s  \
# 63          0       0  7.12    5.34       0      128               1.17
#
#     decoder_latency_s  encoder_throughput  decoder_throughput  \
# 63              0.114                17.9            1.12e+03
#
#    device_memory_ratio
# 63               False
#       model_name  total_params  use_archer dataset_name  dataset_size  \
# 63  nllb-moe-54b     524717009       False        wmt14             1
#
#     dataset_size_after_filter_wrt_input_len src_lang tgt_lang  batch_size  \
# 63                                        1       en       fr           1
#
#     beam_size  max_gen_length  max_input_seq_length tokenizer_padding_setting  \
# 63          1             128                    -1               no_pad_fill
#
#     sacrebleu  spBleu  chrf  chrfpp  meteor  gen_len  encoder_latency_s  \
# 63          0       0  7.12    5.34       0      128               1.17
#
#     decoder_latency_s  encoder_throughput  decoder_throughput  \
# 63              0.114                17.9            1.12e+03
#
#    device_memory_ratio
# 63               False

# %%
print("WORST")

display(df_merge_all_temp.sort_values("encoder_latency_s", ascending=False).head(2))
display(df_merge_all_temp.sort_values("decoder_latency_s", ascending=False).head(2))
display(df_merge_all_temp.sort_values("encoder_throughput").head(2))
display(df_merge_all_temp.sort_values("decoder_throughput").head(2))
# Out:
# WORST
#       model_name  total_params  use_archer dataset_name  dataset_size  \
# 54  nllb-moe-54b     524717009       False        wmt14             1
# 59  nllb-moe-54b     524717009       False        wmt14             1
#
#     dataset_size_after_filter_wrt_input_len src_lang tgt_lang  batch_size  \
# 54                                        1       en       fr           1
# 59                                        1       en       fr           1
#
#     beam_size  max_gen_length  max_input_seq_length tokenizer_padding_setting  \
# 54          1              20                    -1               no_pad_fill
# 59          4              32                    -1               no_pad_fill
#
#     sacrebleu  spBleu  chrf  chrfpp  meteor  gen_len  encoder_latency_s  \
# 54          0       0  12.2    9.17       0       20               63.2
# 59          0       0  12.2    9.14       0       32               63.1
#
#     decoder_latency_s  encoder_throughput  decoder_throughput  \
# 54               2.49               0.332                8.04
# 59               3.49               0.333                9.16
#
#    device_memory_ratio
# 54               False
# 59               False
#       model_name  total_params  use_archer dataset_name  dataset_size  \
# 59  nllb-moe-54b     524717009       False        wmt14             1
# 54  nllb-moe-54b     524717009       False        wmt14             1
#
#     dataset_size_after_filter_wrt_input_len src_lang tgt_lang  batch_size  \
# 59                                        1       en       fr           1
# 54                                        1       en       fr           1
#
#     beam_size  max_gen_length  max_input_seq_length tokenizer_padding_setting  \
# 59          4              32                    -1               no_pad_fill
# 54          1              20                    -1               no_pad_fill
#
#     sacrebleu  spBleu  chrf  chrfpp  meteor  gen_len  encoder_latency_s  \
# 59          0       0  12.2    9.14       0       32               63.1
# 54          0       0  12.2    9.17       0       20               63.2
#
#     decoder_latency_s  encoder_throughput  decoder_throughput  \
# 59               3.49               0.333                9.16
# 54               2.49               0.332                8.04
#
#    device_memory_ratio
# 59               False
# 54               False
#       model_name  total_params  use_archer dataset_name  dataset_size  \
# 54  nllb-moe-54b     524717009       False        wmt14             1
# 59  nllb-moe-54b     524717009       False        wmt14             1
#
#     dataset_size_after_filter_wrt_input_len src_lang tgt_lang  batch_size  \
# 54                                        1       en       fr           1
# 59                                        1       en       fr           1
#
#     beam_size  max_gen_length  max_input_seq_length tokenizer_padding_setting  \
# 54          1              20                    -1               no_pad_fill
# 59          4              32                    -1               no_pad_fill
#
#     sacrebleu  spBleu  chrf  chrfpp  meteor  gen_len  encoder_latency_s  \
# 54          0       0  12.2    9.17       0       20               63.2
# 59          0       0  12.2    9.14       0       32               63.1
#
#     decoder_latency_s  encoder_throughput  decoder_throughput  \
# 54               2.49               0.332                8.04
# 59               3.49               0.333                9.16
#
#    device_memory_ratio
# 54               False
# 59               False
#       model_name  total_params  use_archer dataset_name  dataset_size  \
# 54  nllb-moe-54b     524717009       False        wmt14             1
# 59  nllb-moe-54b     524717009       False        wmt14             1
#
#     dataset_size_after_filter_wrt_input_len src_lang tgt_lang  batch_size  \
# 54                                        1       en       fr           1
# 59                                        1       en       fr           1
#
#     beam_size  max_gen_length  max_input_seq_length tokenizer_padding_setting  \
# 54          1              20                    -1               no_pad_fill
# 59          4              32                    -1               no_pad_fill
#
#     sacrebleu  spBleu  chrf  chrfpp  meteor  gen_len  encoder_latency_s  \
# 54          0       0  12.2    9.17       0       20               63.2
# 59          0       0  12.2    9.14       0       32               63.1
#
#     decoder_latency_s  encoder_throughput  decoder_throughput  \
# 54               2.49               0.332                8.04
# 59               3.49               0.333                9.16
#
#    device_memory_ratio
# 54               False
# 59               False

# %% [markdown]
# Switch inference

# %%
df_merge_all_temp = copy.deepcopy(df_merge_all)
df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("facebook/", "")
df_merge_all_temp["model_name"] = df_merge_all_temp["model_name"].str.replace("google/", "")
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["model_name"] == "switch_16_finetuned"]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["beam_size"] != 8]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["dataset_name"] == "wmt14"]
df_merge_all_temp = df_merge_all_temp[df_merge_all_temp["encoder_throughput"] <1000 ]
df_merge_all_temp = df_merge_all_temp.drop_duplicates(["device_memory_ratio"], keep='first')
display(df_merge_all_temp[["device_memory_ratio"] + speed].sort_values("encoder_latency_s", ascending=False))
display(df_merge_all_temp.sort_values("encoder_latency_s").head(1))
display(df_merge_all_temp.sort_values("decoder_latency_s").head(1))
display(df_merge_all_temp.sort_values("encoder_throughput").head(1))
display(df_merge_all_temp.sort_values("decoder_throughput").head(10000))

# g= sns.barplot(data=df_merge_all_temp, x="device_memory_ratio", y="decoder_latency_s");
# g= sns.jointplot(data=df_merge_all_temp, x="encoder_latency_s", y="decoder_latency_s", hue="device_memory_ratio");
# g= sns.lineplot(data=df_merge_all_temp, x="encoder_latency_s", y="encoder_throughput", hue="device_memory_ratio");
g= sns.scatterplot(data=df_merge_all_temp, x="device_memory_ratio", y="encoder_throughput");

# plt.xticks(df_merge_all_temp["beam_size"])
# plt.xticks(df_merge_all_temp["beam_size"])
# plt.xlim([0, 32])

# g.ax_joint.set_yscale('log')
# g.ax_joint.set_xscale('log')

plt.title("Decoder Latency on Different Sequence Lengths")

# plt.savefig("input_sequence_len_decode_latency.png",
#     dpi=300,
#     bbox_inches="tight")

plt.show()

# plt.xticks(df_merge_all["max_input_seq_length"])
print()
# Out:
#     device_memory_ratio  encoder_latency_s  decoder_latency_s  \
# 105                 0.6               3.48              0.222
# 142                 0.3               3.46               0.23
# 346                 0.9               3.46              0.212
# 319                 0.1              0.266              0.056
#
#      encoder_throughput  decoder_throughput
# 105                5.46                58.6
# 142                5.49                56.6
# 346                5.49                61.3
# 319                71.3                 232
#               model_name  total_params  use_archer dataset_name  dataset_size  \
# 319  switch_16_finetuned           630        True        wmt14             1
#
#      dataset_size_after_filter_wrt_input_len src_lang tgt_lang  batch_size  \
# 319                                        1       en       fr          32
#
#      beam_size  max_gen_length  max_input_seq_length  \
# 319          1              32                    -1
#
#     tokenizer_padding_setting  sacrebleu  spBleu  chrf  chrfpp  meteor  \
# 319               no_pad_fill       9.98    15.7  66.3    57.5   0.385
#
#      gen_len  encoder_latency_s  decoder_latency_s  encoder_throughput  \
# 319       13              0.266              0.056                71.3
#
#      decoder_throughput device_memory_ratio
# 319                 232                 0.1
#               model_name  total_params  use_archer dataset_name  dataset_size  \
# 319  switch_16_finetuned           630        True        wmt14             1
#
#      dataset_size_after_filter_wrt_input_len src_lang tgt_lang  batch_size  \
# 319                                        1       en       fr          32
#
#      beam_size  max_gen_length  max_input_seq_length  \
# 319          1              32                    -1
#
#     tokenizer_padding_setting  sacrebleu  spBleu  chrf  chrfpp  meteor  \
# 319               no_pad_fill       9.98    15.7  66.3    57.5   0.385
#
#      gen_len  encoder_latency_s  decoder_latency_s  encoder_throughput  \
# 319       13              0.266              0.056                71.3
#
#      decoder_throughput device_memory_ratio
# 319                 232                 0.1
#               model_name  total_params  use_archer dataset_name  dataset_size  \
# 105  switch_16_finetuned           630        True        wmt14             1
#
#      dataset_size_after_filter_wrt_input_len src_lang tgt_lang  batch_size  \
# 105                                        1       en       fr          32
#
#      beam_size  max_gen_length  max_input_seq_length  \
# 105          1              32                    -1
#
#     tokenizer_padding_setting  sacrebleu  spBleu  chrf  chrfpp  meteor  \
# 105               no_pad_fill       9.98    15.7  66.3    57.5   0.385
#
#      gen_len  encoder_latency_s  decoder_latency_s  encoder_throughput  \
# 105       13               3.48              0.222                5.46
#
#      decoder_throughput device_memory_ratio
# 105                58.6                 0.6
#               model_name  total_params  use_archer dataset_name  dataset_size  \
# 142  switch_16_finetuned           630        True        wmt14             1
# 105  switch_16_finetuned           630        True        wmt14             1
# 346  switch_16_finetuned           630        True        wmt14             1
# 319  switch_16_finetuned           630        True        wmt14             1
#
#      dataset_size_after_filter_wrt_input_len src_lang tgt_lang  batch_size  \
# 142                                        1       en       fr          32
# 105                                        1       en       fr          32
# 346                                        1       en       fr          32
# 319                                        1       en       fr          32
#
#      beam_size  max_gen_length  max_input_seq_length  \
# 142          1              32                    -1
# 105          1              32                    -1
# 346          1              32                    -1
# 319          1              32                    -1
#
#     tokenizer_padding_setting  sacrebleu  spBleu  chrf  chrfpp  meteor  \
# 142               no_pad_fill       9.98    15.7  66.3    57.5   0.385
# 105               no_pad_fill       9.98    15.7  66.3    57.5   0.385
# 346               no_pad_fill       9.98    15.7  66.3    57.5   0.385
# 319               no_pad_fill       9.98    15.7  66.3    57.5   0.385
#
#      gen_len  encoder_latency_s  decoder_latency_s  encoder_throughput  \
# 142       13               3.46               0.23                5.49
# 105       13               3.48              0.222                5.46
# 346       13               3.46              0.212                5.49
# 319       13              0.266              0.056                71.3
#
#      decoder_throughput device_memory_ratio
# 142                56.6                 0.3
# 105                58.6                 0.6
# 346                61.3                 0.9
# 319                 232                 0.1

# %% [markdown]
# ## Extra

# %%
# # Create subplots for different metrics
# fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))

# # Plot 1: sacrebleu vs beam_size
# data.plot(x='beam_size', y='sacrebleu', kind='bar', ax=axes[0, 0], title='sacrebleu vs beam_size')
# axes[0, 0].set_xlabel('Beam Size')
# axes[0, 0].set_ylabel('sacrebleu')

# # Plot 2: spBleu vs beam_size
# data.plot(x='beam_size', y='spBleu', kind='line', ax=axes[0, 1], title='spBleu vs beam_size')
# axes[0, 1].set_xlabel('Beam Size')
# axes[0, 1].set_ylabel('spBleu')

# # Plot 3: chrf vs beam_size
# data.plot(x='beam_size', y='chrf', kind='line', ax=axes[1, 0], title='chrf vs beam_size')
# axes[1, 0].set_xlabel('Beam Size')
# axes[1, 0].set_ylabel('chrf')

# # Plot 4: chrfpp vs beam_size
# data.plot(x='beam_size', y='chrfpp', kind='line', ax=axes[1, 1], title='chrfpp vs beam_size')
# axes[1, 1].set_xlabel('Beam Size')
# axes[1, 1].set_ylabel('chrfpp')

# # Adjust layout
# plt.tight_layout()

# # Show the plots
# plt.show()

# Calculate mean and standard deviation of each metric
metrics = ['sacrebleu', 'spBleu', 'chrf', 'chrfpp', 'meteor']
for metric in metrics:
    mean = data[metric].mean()
    std = data[metric].std()
    print(f"Metric: {metric}\nMean: {mean:.2f}\nStandard Deviation: {std:.2f}\n")
# Out:
# Metric: sacrebleu
# Mean: 34.64
# Standard Deviation: 9.18
#
# Metric: spBleu
# Mean: 37.82
# Standard Deviation: 6.94
#
# Metric: chrf
# Mean: 65.30
# Standard Deviation: 3.49
#
# Metric: chrfpp
# Mean: 62.60
# Standard Deviation: 4.52
#
# Metric: meteor
# Mean: 0.64
# Standard Deviation: 0.09

# %%
# Find the row with the highest value for each metric
best_hyperparameters = {}
for metric in metrics:
    best_row = data[data[metric] == data[metric].max()]  # Assumes higher value is better
    best_hyperparameters[metric] = best_row.iloc[0]

# Display the best hyperparameters for each metric
for metric, best_row in best_hyperparameters.items():
    print(f"Best hyperparameters for {metric}:")
    print(best_row)
    print("\n")
# Out:
# Best hyperparameters for sacrebleu:
# model_name                                 facebook/nllb-200-distilled-600M
# total_params                                                      615073792
# dataset_name                                                      flores200
# dataset_size                                                            997
# dataset_size_after_filter_wrt_input_len                                 997
# src_lang                                                                 en
# tgt_lang                                                                 fr
# batch_size                                                               32
# beam_size                                                                 4
# max_gen_length                                                          128
# max_input_seq_length                                                     -1
# tokenizer_padding_setting                                 pad_to_max_length
# sacrebleu                                                         41.566994
# spBleu                                                            43.451374
# chrf                                                              68.200892
# chrfpp                                                            66.091879
# meteor                                                             0.699627
# gen_len                                                           47.752257
# encoder_latency_s                                                  0.010812
# decoder_latency_s                                                  0.005733
# encoder_throughput                                                3411197.8
# decoder_throughput                                           8303666.771504
# Name: 8, dtype: object
#
#
# Best hyperparameters for spBleu:
# model_name                                 facebook/nllb-200-distilled-600M
# total_params                                                      615073792
# dataset_name                                                      flores200
# dataset_size                                                            997
# dataset_size_after_filter_wrt_input_len                                 997
# src_lang                                                                 en
# tgt_lang                                                                 fr
# batch_size                                                               32
# beam_size                                                                 4
# max_gen_length                                                          128
# max_input_seq_length                                                     -1
# tokenizer_padding_setting                                 pad_to_max_length
# sacrebleu                                                         41.566994
# spBleu                                                            43.451374
# chrf                                                              68.200892
# chrfpp                                                            66.091879
# meteor                                                             0.699627
# gen_len                                                           47.752257
# encoder_latency_s                                                  0.010812
# decoder_latency_s                                                  0.005733
# encoder_throughput                                                3411197.8
# decoder_throughput                                           8303666.771504
# Name: 8, dtype: object
#
#
# Best hyperparameters for chrf:
# model_name                                 facebook/nllb-200-distilled-600M
# total_params                                                      615073792
# dataset_name                                                      flores200
# dataset_size                                                            997
# dataset_size_after_filter_wrt_input_len                                 997
# src_lang                                                                 en
# tgt_lang                                                                 fr
# batch_size                                                               32
# beam_size                                                                 4
# max_gen_length                                                          128
# max_input_seq_length                                                     -1
# tokenizer_padding_setting                                 pad_to_max_length
# sacrebleu                                                         41.566994
# spBleu                                                            43.451374
# chrf                                                              68.200892
# chrfpp                                                            66.091879
# meteor                                                             0.699627
# gen_len                                                           47.752257
# encoder_latency_s                                                  0.010812
# decoder_latency_s                                                  0.005733
# encoder_throughput                                                3411197.8
# decoder_throughput                                           8303666.771504
# Name: 8, dtype: object
#
#
# Best hyperparameters for chrfpp:
# model_name                                 facebook/nllb-200-distilled-600M
# total_params                                                      615073792
# dataset_name                                                      flores200
# dataset_size                                                            997
# dataset_size_after_filter_wrt_input_len                                 997
# src_lang                                                                 en
# tgt_lang                                                                 fr
# batch_size                                                               32
# beam_size                                                                 4
# max_gen_length                                                          128
# max_input_seq_length                                                     -1
# tokenizer_padding_setting                                 pad_to_max_length
# sacrebleu                                                         41.566994
# spBleu                                                            43.451374
# chrf                                                              68.200892
# chrfpp                                                            66.091879
# meteor                                                             0.699627
# gen_len                                                           47.752257
# encoder_latency_s                                                  0.010812
# decoder_latency_s                                                  0.005733
# encoder_throughput                                                3411197.8
# decoder_throughput                                           8303666.771504
# Name: 8, dtype: object
#
#
# Best hyperparameters for meteor:
# model_name                                 facebook/nllb-200-distilled-600M
# total_params                                                      615073792
# dataset_name                                                      flores200
# dataset_size                                                            997
# dataset_size_after_filter_wrt_input_len                                 199
# src_lang                                                                 en
# tgt_lang                                                                 fr
# batch_size                                                               32
# beam_size                                                                 4
# max_gen_length                                                          128
# max_input_seq_length                                                     15
# tokenizer_padding_setting                                 pad_to_max_length
# sacrebleu                                                         38.011731
# spBleu                                                            39.247613
# chrf                                                              67.898121
# chrfpp                                                            65.833887
# meteor                                                             0.709543
# gen_len                                                           34.517588
# encoder_latency_s                                                  0.005878
# decoder_latency_s                                                  0.005778
# encoder_throughput                                                871952.56
# decoder_throughput                                           1188824.278565
# Name: 14, dtype: object

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample data

# Calculate the ECDF
x = np.sort(df_merge_wmt14_single_sentence["encoder_throughput"])
y = np.arange(1, len(x) + 1) / len(x)
print(y)
# Create the ECDF plot
plt.plot(x, y, marker='o', linestyle='none')
plt.xlabel('Variable Values')
plt.ylabel('ECDF')
plt.title('ECDF Plot')
plt.margins(0.02)  # Add a small margin around the plot
plt.grid(True)
plt.show()
# Out:
# [0.01666667 0.03333333 0.05       0.06666667 0.08333333 0.1
#  0.11666667 0.13333333 0.15       0.16666667 0.18333333 0.2
#  0.21666667 0.23333333 0.25       0.26666667 0.28333333 0.3
#  0.31666667 0.33333333 0.35       0.36666667 0.38333333 0.4
#  0.41666667 0.43333333 0.45       0.46666667 0.48333333 0.5
#  0.51666667 0.53333333 0.55       0.56666667 0.58333333 0.6
#  0.61666667 0.63333333 0.65       0.66666667 0.68333333 0.7
#  0.71666667 0.73333333 0.75       0.76666667 0.78333333 0.8
#  0.81666667 0.83333333 0.85       0.86666667 0.88333333 0.9
#  0.91666667 0.93333333 0.95       0.96666667 0.98333333 1.        ]

# %%
# Out:
# hello

# %%
0.1 errors out. for nllb-moe device memory ratio
